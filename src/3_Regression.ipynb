# %%
import pandas as pd
from pytz import timezone
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import ast
import re
from dateutil import parser
from datetime import datetime, timedelta
import numpy as np
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
import csv

# Specify the file path of the CSV file
file_path = 'top_sellers.csv'

# Open the CSV file in read mode and read the data
with open(file_path, 'r') as csvfile:
    reader = csv.reader(csvfile)
    data = next(reader)

# 'data' will contain the list of strings from the CSV file
data = list(map(int, data))

# %%
## 2023-06-28 start from here
merged_df = pd.read_csv('merged_df3834.csv')

# %%
merged_df
# Out:
#           product_id            timestamp  year  month  day  hour  \
# 0                  0  2022-01-01 00:00:00  2022      1    1     0
# 1                  0  2022-01-01 01:00:00  2022      1    1     1
# 2                  0  2022-01-01 02:00:00  2022      1    1     2
# 3                  0  2022-01-01 03:00:00  2022      1    1     3
# 4                  0  2022-01-01 04:00:00  2022      1    1     4
# ...              ...                  ...   ...    ...  ...   ...
# 38219875         999  2022-12-31 19:00:00  2022     12   31    19
# 38219876         999  2022-12-31 20:00:00  2022     12   31    20
# 38219877         999  2022-12-31 21:00:00  2022     12   31    21
# 38219878         999  2022-12-31 22:00:00  2022     12   31    22
# 38219879         999  2022-12-31 23:00:00  2022     12   31    23
#
#           day_of_week  hourly_sales  instock_fraction
# 0                   5           0.0               1.0
# 1                   5           0.0               1.0
# 2                   5           0.0               1.0
# 3                   5           0.0               1.0
# 4                   5           0.0               1.0
# ...               ...           ...               ...
# 38219875            5           0.0               1.0
# 38219876            5           0.0               1.0
# 38219877            5           0.0               1.0
# 38219878            5           0.0               1.0
# 38219879            5           0.0               1.0
#
# [38219880 rows x 9 columns]

# %%
merged_df['stockout_dum'] = (1 - merged_df['instock_fraction']).gt(1/60).astype(int)

# %%
df_cooccurrence_of667 = pd.read_csv("final_co_occurrence_ratio_for_3834.csv")

# %%
df_sorted = df_cooccurrence_of667.sort_values('co_occurrence_ratio_wrt_product_1', ascending=False)

top = 11
# Get the 40 biggest 'idpx' values
top_biggest = df_sorted[1:top]['product_id_2']

top_biggest
# Out:
# 1      610
# 2     1610
# 3     2668
# 4      752
# 5      106
# 6     2571
# 7      463
# 8      523
# 9     4144
# 10     252
# Name: product_id_2, dtype: int64

# %%
merged_df['com_dum']=0
merged_df.loc[merged_df['product_id'].isin(top_biggest),'com_dum']=1

merged_df['stockout_com_interaction'] = merged_df['stockout_dum']*merged_df['com_dum']
merged_df
# Out:
#           product_id            timestamp  year  month  day  hour  \
# 0                  0  2022-01-01 00:00:00  2022      1    1     0
# 1                  0  2022-01-01 01:00:00  2022      1    1     1
# 2                  0  2022-01-01 02:00:00  2022      1    1     2
# 3                  0  2022-01-01 03:00:00  2022      1    1     3
# 4                  0  2022-01-01 04:00:00  2022      1    1     4
# ...              ...                  ...   ...    ...  ...   ...
# 38219875         999  2022-12-31 19:00:00  2022     12   31    19
# 38219876         999  2022-12-31 20:00:00  2022     12   31    20
# 38219877         999  2022-12-31 21:00:00  2022     12   31    21
# 38219878         999  2022-12-31 22:00:00  2022     12   31    22
# 38219879         999  2022-12-31 23:00:00  2022     12   31    23
#
#           day_of_week  hourly_sales  instock_fraction  stockout_dum  com_dum  \
# 0                   5           0.0               1.0             0        0
# 1                   5           0.0               1.0             0        0
# 2                   5           0.0               1.0             0        0
# 3                   5           0.0               1.0             0        0
# 4                   5           0.0               1.0             0        0
# ...               ...           ...               ...           ...      ...
# 38219875            5           0.0               1.0             0        0
# 38219876            5           0.0               1.0             0        0
# 38219877            5           0.0               1.0             0        0
# 38219878            5           0.0               1.0             0        0
# 38219879            5           0.0               1.0             0        0
#
#           stockout_com_interaction
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ...                            ...
# 38219875                         0
# 38219876                         0
# 38219877                         0
# 38219878                         0
# 38219879                         0
#
# [38219880 rows x 12 columns]

# %%
merged_df = merged_df[merged_df['product_id'].isin(data)]

merged_df.shape
# Out:
# (3504000, 12)

# %% [markdown]
# # Regression
#
# $ln(hourly\_sales_{p,t}) = \beta_0 + \beta_1 * stockout\_dum\_t + \beta_2 * comp\_dum\_p+\beta_3 * stockout\_dum\_t * comp\_dum\_p + \delta\_prod(p) +\gamma\_m(t) + \theta\_d(t) + \alpha\_dow(t) + \delta\_h(t) + ε_{p,t}$
#
# Y_{p,t}:  represents the outcome variable which is log hourly sales for each product p at time t.
#
# $stockout\_dum\_t$: is a dummy variable that equals 1 if the order was placed when stockout.
#
# $comp\_dum\_p$: is a dummy variable that equals 1 if product p is complementary of the independant variable.
#
# $\delta\_prod(p)$: fixed effect of products.
#
# $\gamma\_m(t)$: fixed effect of month.
#
# $\theta\_d(t)$: fixed effect of day.
#
# $\alpha\_dow(t)$: fixed effect of day of week.
#
# $\delta\_h(t)$: fixed effect of hour.
#
# ε_it represents the error term.

# %%
df_regression = merged_df.copy()

df_regression = df_regression[df_regression['product_id']!=3834]

# %%
df_regression_2022 = df_regression[(df_regression['year']==2022)]

# %%
df_regression_2022 = df_regression_2022[df_regression_2022['month'].isin([1,2,3,4,5,6])]
#df_regression_2022 = df_regression_2022[df_regression_2022['month'].isin([2])]

# %%
df_regression_2022 = df_regression_2022.drop(['timestamp','instock_fraction','year'], axis=1)

# %%
month_dummies = pd.get_dummies(df_regression_2022['month'], prefix='month', drop_first=True)
#day_dummies = pd.get_dummies(df_regression_2022['day'], prefix='day', drop_first=True)
day_of_week_dummies = pd.get_dummies(df_regression_2022['day_of_week'], prefix='day', drop_first=True)
hour_dummies = pd.get_dummies(df_regression_2022['hour'], prefix='hour', drop_first=True)
product_id_dummies = pd.get_dummies(df_regression_2022['product_id'], prefix='product_id', drop_first=True)

# Concatenate the dummy variables with the original DataFrame
df_with_dummies = pd.concat([df_regression_2022, month_dummies, day_of_week_dummies, hour_dummies, product_id_dummies], axis=1)

# Log-transform the dependent variable
df_with_dummies['log_hourly_sales'] = np.log(1 + df_with_dummies['hourly_sales'])

# Create the design matrix by specifying the formula with interaction terms
formula = 'log_hourly_sales ~ stockout_dum + com_dum + stockout_com_interaction + C(product_id) + C(month) + C(day_of_week) + C(hour)'

# %%
# Fit the linear regression model
results = smf.ols(formula=formula, data=df_with_dummies).fit()

# Get the summary of the regression results
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       log_hourly_sales   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.166
# Method:                 Least Squares   F-statistic:                     795.1
# Date:                Tue, 04 Jul 2023   Prob (F-statistic):               0.00
# Time:                        09:06:58   Log-Likelihood:            -4.4192e+05
# No. Observations:             1733256   AIC:                         8.847e+05
# Df Residuals:                 1732820   BIC:                         8.901e+05
# Df Model:                         435
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.0038      0.005     -0.776      0.438      -0.014       0.006
# C(product_id)[T.3]           0.0187      0.007      2.789      0.005       0.006       0.032
# C(product_id)[T.23]         -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.43]         -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.45]         -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.54]         -0.0168      0.007     -2.503      0.012      -0.030      -0.004
# C(product_id)[T.59]         -0.0011      0.007     -0.166      0.868      -0.014       0.012
# C(product_id)[T.78]          0.0771      0.007     11.508      0.000       0.064       0.090
# C(product_id)[T.85]         -0.0123      0.007     -1.837      0.066      -0.025       0.001
# C(product_id)[T.86]         -0.0331      0.007     -4.943      0.000      -0.046      -0.020
# C(product_id)[T.89]          0.0248      0.007      3.695      0.000       0.012       0.038
# C(product_id)[T.125]         0.0045      0.007      0.676      0.499      -0.009       0.018
# C(product_id)[T.133]        -0.0037      0.007     -0.546      0.585      -0.017       0.009
# C(product_id)[T.139]         0.0661      0.007      9.866      0.000       0.053       0.079
# C(product_id)[T.147]        -0.0310      0.007     -4.626      0.000      -0.044      -0.018
# C(product_id)[T.161]         0.0455      0.007      6.787      0.000       0.032       0.059
# C(product_id)[T.174]         0.0561      0.007      8.370      0.000       0.043       0.069
# C(product_id)[T.204]        -0.0107      0.007     -1.590      0.112      -0.024       0.002
# C(product_id)[T.206]        -0.0121      0.007     -1.812      0.070      -0.025       0.001
# C(product_id)[T.210]        -0.0098      0.007     -1.465      0.143      -0.023       0.003
# C(product_id)[T.218]         0.0041      0.007      0.605      0.545      -0.009       0.017
# C(product_id)[T.245]         0.0167      0.007      2.495      0.013       0.004       0.030
# C(product_id)[T.246]         0.0105      0.007      1.571      0.116      -0.003       0.024
# C(product_id)[T.249]        -0.0215      0.007     -3.211      0.001      -0.035      -0.008
# C(product_id)[T.252]       1.17e+08   4.43e+08      0.264      0.792   -7.52e+08    9.86e+08
# C(product_id)[T.270]         0.0160      0.007      2.387      0.017       0.003       0.029
# C(product_id)[T.273]         0.0408      0.007      6.082      0.000       0.028       0.054
# C(product_id)[T.274]         0.1491      0.007     22.248      0.000       0.136       0.162
# C(product_id)[T.275]         0.2213      0.007     33.027      0.000       0.208       0.234
# C(product_id)[T.278]         0.0014      0.007      0.206      0.836      -0.012       0.015
# C(product_id)[T.288]         0.1062      0.007     15.840      0.000       0.093       0.119
# C(product_id)[T.291]         0.0493      0.007      7.362      0.000       0.036       0.062
# C(product_id)[T.299]        -0.0146      0.007     -2.176      0.030      -0.028      -0.001
# C(product_id)[T.314]        -0.0261      0.007     -3.900      0.000      -0.039      -0.013
# C(product_id)[T.338]        -0.0256      0.007     -3.825      0.000      -0.039      -0.012
# C(product_id)[T.347]         0.0351      0.007      5.231      0.000       0.022       0.048
# C(product_id)[T.355]         0.0145      0.007      2.156      0.031       0.001       0.028
# C(product_id)[T.362]         0.0682      0.007     10.173      0.000       0.055       0.081
# C(product_id)[T.375]        -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.377]        -0.0138      0.007     -2.059      0.040      -0.027      -0.001
# C(product_id)[T.378]         0.0981      0.007     14.638      0.000       0.085       0.111
# C(product_id)[T.387]         0.0021      0.007      0.311      0.756      -0.011       0.015
# C(product_id)[T.397]        -0.0101      0.007     -1.506      0.132      -0.023       0.003
# C(product_id)[T.404]        -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.407]        -0.0216      0.007     -3.222      0.001      -0.035      -0.008
# C(product_id)[T.418]        -0.0193      0.007     -2.882      0.004      -0.032      -0.006
# C(product_id)[T.429]        -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.430]        -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.433]         0.0073      0.007      1.082      0.279      -0.006       0.020
# C(product_id)[T.441]         0.0214      0.007      3.191      0.001       0.008       0.035
# C(product_id)[T.447]         0.0072      0.007      1.072      0.284      -0.006       0.020
# C(product_id)[T.460]        -0.0127      0.007     -1.897      0.058      -0.026       0.000
# C(product_id)[T.462]         0.0186      0.007      2.775      0.006       0.005       0.032
# C(product_id)[T.475]         0.0650      0.007      9.704      0.000       0.052       0.078
# C(product_id)[T.493]         0.0170      0.007      2.536      0.011       0.004       0.030
# C(product_id)[T.495]         0.2523      0.007     37.651      0.000       0.239       0.265
# C(product_id)[T.496]         0.0289      0.007      4.308      0.000       0.016       0.042
# C(product_id)[T.515]        -0.0132      0.007     -1.966      0.049      -0.026   -3.85e-05
# C(product_id)[T.523]       1.17e+08   4.43e+08      0.264      0.792   -7.52e+08    9.86e+08
# C(product_id)[T.528]         0.5292      0.007     78.958      0.000       0.516       0.542
# C(product_id)[T.530]         0.1460      0.007     21.786      0.000       0.133       0.159
# C(product_id)[T.537]         0.0101      0.007      1.511      0.131      -0.003       0.023
# C(product_id)[T.560]         0.0580      0.007      8.655      0.000       0.045       0.071
# C(product_id)[T.561]         0.0429      0.007      6.400      0.000       0.030       0.056
# C(product_id)[T.567]         0.0205      0.007      3.064      0.002       0.007       0.034
# C(product_id)[T.580]        -0.0470      0.007     -7.016      0.000      -0.060      -0.034
# C(product_id)[T.587]        -0.0021      0.007     -0.311      0.756      -0.015       0.011
# C(product_id)[T.594]        -0.0159      0.007     -2.377      0.017      -0.029      -0.003
# C(product_id)[T.602]         0.0004      0.007      0.061      0.952      -0.013       0.014
# C(product_id)[T.604]        -0.0075      0.007     -1.126      0.260      -0.021       0.006
# C(product_id)[T.623]         0.0423      0.007      6.311      0.000       0.029       0.055
# C(product_id)[T.629]        -0.0124      0.007     -1.854      0.064      -0.026       0.001
# C(product_id)[T.646]        -0.0162      0.007     -2.414      0.016      -0.029      -0.003
# C(product_id)[T.650]         0.0206      0.007      3.081      0.002       0.008       0.034
# C(product_id)[T.667]         1.3493      0.007    201.328      0.000       1.336       1.362
# C(product_id)[T.687]        -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.688]         0.1649      0.007     24.612      0.000       0.152       0.178
# C(product_id)[T.695]         0.0123      0.007      1.832      0.067      -0.001       0.025
# C(product_id)[T.699]        -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.703]        -0.0037      0.007     -0.558      0.577      -0.017       0.009
# C(product_id)[T.708]        -0.0436      0.007     -6.508      0.000      -0.057      -0.030
# C(product_id)[T.716]         0.0064      0.007      0.951      0.342      -0.007       0.020
# C(product_id)[T.719]         0.7409      0.007    110.546      0.000       0.728       0.754
# C(product_id)[T.735]         0.2405      0.007     35.878      0.000       0.227       0.254
# C(product_id)[T.739]        -0.0311      0.007     -4.645      0.000      -0.044      -0.018
# C(product_id)[T.752]       1.17e+08   4.43e+08      0.264      0.792   -7.52e+08    9.86e+08
# C(product_id)[T.777]        -0.0013      0.007     -0.190      0.849      -0.014       0.012
# C(product_id)[T.780]        -0.0292      0.007     -4.364      0.000      -0.042      -0.016
# C(product_id)[T.789]        -0.0062      0.007     -0.920      0.358      -0.019       0.007
# C(product_id)[T.820]        -0.0057      0.007     -0.854      0.393      -0.019       0.007
# C(product_id)[T.821]         0.0047      0.007      0.705      0.481      -0.008       0.018
# C(product_id)[T.826]         0.0098      0.007      1.457      0.145      -0.003       0.023
# C(product_id)[T.871]        -0.0184      0.007     -2.746      0.006      -0.032      -0.005
# C(product_id)[T.880]         0.0187      0.007      2.797      0.005       0.006       0.032
# C(product_id)[T.887]        -0.0113      0.007     -1.690      0.091      -0.024       0.002
# C(product_id)[T.900]        -0.0159      0.007     -2.368      0.018      -0.029      -0.003
# C(product_id)[T.912]         0.0796      0.007     11.881      0.000       0.066       0.093
# C(product_id)[T.928]         0.0036      0.007      0.538      0.590      -0.010       0.017
# C(product_id)[T.944]         0.0275      0.007      4.100      0.000       0.014       0.041
# C(product_id)[T.962]         0.0162      0.007      2.413      0.016       0.003       0.029
# C(product_id)[T.971]         0.0367      0.007      5.479      0.000       0.024       0.050
# C(product_id)[T.982]        -0.0034      0.007     -0.505      0.613      -0.017       0.010
# C(product_id)[T.994]        -0.0046      0.007     -0.690      0.490      -0.018       0.009
# C(product_id)[T.1001]        0.0276      0.007      4.123      0.000       0.014       0.041
# C(product_id)[T.1031]       -0.0019      0.007     -0.277      0.782      -0.015       0.011
# C(product_id)[T.1061]        0.0149      0.007      2.230      0.026       0.002       0.028
# C(product_id)[T.1064]       -0.0046      0.007     -0.693      0.488      -0.018       0.008
# C(product_id)[T.1084]        0.0207      0.007      3.086      0.002       0.008       0.034
# C(product_id)[T.1091]       -0.0111      0.007     -1.650      0.099      -0.024       0.002
# C(product_id)[T.1093]        0.0389      0.007      5.806      0.000       0.026       0.052
# C(product_id)[T.1094]        0.1127      0.007     16.812      0.000       0.100       0.126
# C(product_id)[T.1114]       -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.1115]        0.0313      0.007      4.667      0.000       0.018       0.044
# C(product_id)[T.1124]        0.0443      0.007      6.603      0.000       0.031       0.057
# C(product_id)[T.1149]        0.1678      0.007     25.040      0.000       0.155       0.181
# C(product_id)[T.1151]        0.1641      0.007     24.487      0.000       0.151       0.177
# C(product_id)[T.1161]       -0.0025      0.007     -0.379      0.704      -0.016       0.011
# C(product_id)[T.1163]       -0.0097      0.007     -1.448      0.148      -0.023       0.003
# C(product_id)[T.1165]        0.0238      0.007      3.549      0.000       0.011       0.037
# C(product_id)[T.1197]       -0.0192      0.007     -2.868      0.004      -0.032      -0.006
# C(product_id)[T.1211]        0.0485      0.007      7.240      0.000       0.035       0.062
# C(product_id)[T.1216]       -0.0102      0.007     -1.529      0.126      -0.023       0.003
# C(product_id)[T.1219]        0.0085      0.007      1.274      0.203      -0.005       0.022
# C(product_id)[T.1262]        0.0249      0.007      3.715      0.000       0.012       0.038
# C(product_id)[T.1279]        0.6967      0.007    103.952      0.000       0.684       0.710
# C(product_id)[T.1280]        0.8536      0.007    127.374      0.000       0.840       0.867
# C(product_id)[T.1288]       -0.0201      0.007     -3.000      0.003      -0.033      -0.007
# C(product_id)[T.1291]        0.0156      0.007      2.326      0.020       0.002       0.029
# C(product_id)[T.1304]       -0.0155      0.007     -2.307      0.021      -0.029      -0.002
# C(product_id)[T.1305]       -0.0064      0.007     -0.961      0.337      -0.020       0.007
# C(product_id)[T.1307]        0.1522      0.007     22.706      0.000       0.139       0.165
# C(product_id)[T.1309]        0.0098      0.007      1.462      0.144      -0.003       0.023
# C(product_id)[T.1314]       -0.0037      0.007     -0.559      0.576      -0.017       0.009
# C(product_id)[T.1336]        0.0756      0.007     11.282      0.000       0.062       0.089
# C(product_id)[T.1355]        0.1328      0.007     19.814      0.000       0.120       0.146
# C(product_id)[T.1366]       -0.0051      0.007     -0.759      0.448      -0.018       0.008
# C(product_id)[T.1369]        0.0070      0.007      1.043      0.297      -0.006       0.020
# C(product_id)[T.1370]        0.0667      0.007      9.956      0.000       0.054       0.080
# C(product_id)[T.1384]       -0.0219      0.007     -3.262      0.001      -0.035      -0.009
# C(product_id)[T.1414]        0.1786      0.007     26.644      0.000       0.165       0.192
# C(product_id)[T.1454]        0.0499      0.007      7.445      0.000       0.037       0.063
# C(product_id)[T.1462]        0.0458      0.007      6.829      0.000       0.033       0.059
# C(product_id)[T.1487]        0.0278      0.007      4.154      0.000       0.015       0.041
# C(product_id)[T.1506]        0.0849      0.007     12.675      0.000       0.072       0.098
# C(product_id)[T.1514]       -0.0074      0.007     -1.104      0.270      -0.021       0.006
# C(product_id)[T.1515]        0.0616      0.007      9.186      0.000       0.048       0.075
# C(product_id)[T.1516]        0.0247      0.007      3.688      0.000       0.012       0.038
# C(product_id)[T.1517]       -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.1541]        0.0613      0.007      9.151      0.000       0.048       0.074
# C(product_id)[T.1542]        0.0118      0.007      1.768      0.077      -0.001       0.025
# C(product_id)[T.1570]        0.0531      0.007      7.930      0.000       0.040       0.066
# C(product_id)[T.1574]        0.0501      0.007      7.472      0.000       0.037       0.063
# C(product_id)[T.1578]       -0.0060      0.007     -0.896      0.370      -0.019       0.007
# C(product_id)[T.1588]        0.1018      0.007     15.193      0.000       0.089       0.115
# C(product_id)[T.1610]      1.17e+08   4.43e+08      0.264      0.792   -7.52e+08    9.86e+08
# C(product_id)[T.1621]        0.2065      0.007     30.809      0.000       0.193       0.220
# C(product_id)[T.1652]        0.0226      0.007      3.375      0.001       0.009       0.036
# C(product_id)[T.1664]       -0.0078      0.007     -1.165      0.244      -0.021       0.005
# C(product_id)[T.1669]        0.0533      0.007      7.957      0.000       0.040       0.066
# C(product_id)[T.1677]        0.0220      0.007      3.286      0.001       0.009       0.035
# C(product_id)[T.1689]       -0.0559      0.007     -8.347      0.000      -0.069      -0.043
# C(product_id)[T.1706]       -0.0264      0.007     -3.946      0.000      -0.040      -0.013
# C(product_id)[T.1714]        0.0138      0.007      2.053      0.040       0.001       0.027
# C(product_id)[T.1715]        0.0467      0.007      6.964      0.000       0.034       0.060
# C(product_id)[T.1749]       -0.0171      0.007     -2.553      0.011      -0.030      -0.004
# C(product_id)[T.1764]        0.0958      0.007     14.300      0.000       0.083       0.109
# C(product_id)[T.1779]       -0.0165      0.007     -2.463      0.014      -0.030      -0.003
# C(product_id)[T.1816]        0.0006      0.007      0.090      0.928      -0.013       0.014
# C(product_id)[T.1866]       -0.0027      0.007     -0.401      0.688      -0.016       0.010
# C(product_id)[T.1893]        0.0171      0.007      2.555      0.011       0.004       0.030
# C(product_id)[T.1899]        0.0318      0.007      4.744      0.000       0.019       0.045
# C(product_id)[T.1904]        0.0403      0.007      6.006      0.000       0.027       0.053
# C(product_id)[T.1947]       -0.0144      0.007     -2.153      0.031      -0.028      -0.001
# C(product_id)[T.1948]        0.2440      0.007     36.416      0.000       0.231       0.257
# C(product_id)[T.1951]        0.0009      0.007      0.134      0.893      -0.012       0.014
# C(product_id)[T.1960]       -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.1985]       -0.0167      0.007     -2.497      0.013      -0.030      -0.004
# C(product_id)[T.1990]       -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.1996]       -0.0127      0.007     -1.896      0.058      -0.026       0.000
# C(product_id)[T.2004]       -0.0033      0.007     -0.492      0.622      -0.016       0.010
# C(product_id)[T.2017]        0.0070      0.007      1.045      0.296      -0.006       0.020
# C(product_id)[T.2019]        0.0708      0.007     10.559      0.000       0.058       0.084
# C(product_id)[T.2023]        0.0073      0.007      1.094      0.274      -0.006       0.020
# C(product_id)[T.2033]       -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.2044]       -0.0251      0.007     -3.748      0.000      -0.038      -0.012
# C(product_id)[T.2046]       -0.0417      0.007     -6.220      0.000      -0.055      -0.029
# C(product_id)[T.2047]        0.0539      0.007      8.048      0.000       0.041       0.067
# C(product_id)[T.2071]       -0.0045      0.007     -0.679      0.497      -0.018       0.009
# C(product_id)[T.2075]       -0.0172      0.007     -2.574      0.010      -0.030      -0.004
# C(product_id)[T.2091]        0.0209      0.007      3.122      0.002       0.008       0.034
# C(product_id)[T.2099]       -0.0023      0.007     -0.341      0.733      -0.015       0.011
# C(product_id)[T.2104]        0.0384      0.007      5.734      0.000       0.025       0.052
# C(product_id)[T.2126]        0.0766      0.007     11.429      0.000       0.063       0.090
# C(product_id)[T.2135]       -0.0136      0.007     -2.033      0.042      -0.027      -0.000
# C(product_id)[T.2137]        0.0005      0.007      0.081      0.936      -0.013       0.014
# C(product_id)[T.2139]       -0.0153      0.007     -2.288      0.022      -0.028      -0.002
# C(product_id)[T.2146]        0.0235      0.007      3.507      0.000       0.010       0.037
# C(product_id)[T.2151]        0.0372      0.007      5.554      0.000       0.024       0.050
# C(product_id)[T.2155]       -0.0080      0.007     -1.187      0.235      -0.021       0.005
# C(product_id)[T.2173]        0.0120      0.007      1.789      0.074      -0.001       0.025
# C(product_id)[T.2177]        0.0368      0.007      5.488      0.000       0.024       0.050
# C(product_id)[T.2210]        0.0228      0.007      3.403      0.001       0.010       0.036
# C(product_id)[T.2215]       -0.0117      0.007     -1.752      0.080      -0.025       0.001
# C(product_id)[T.2221]        0.0218      0.007      3.252      0.001       0.009       0.035
# C(product_id)[T.2240]       -0.0094      0.007     -1.395      0.163      -0.022       0.004
# C(product_id)[T.2259]       -0.0014      0.007     -0.203      0.839      -0.014       0.012
# C(product_id)[T.2272]       -0.0527      0.007     -7.856      0.000      -0.066      -0.040
# C(product_id)[T.2279]       -0.0155      0.007     -2.306      0.021      -0.029      -0.002
# C(product_id)[T.2286]       -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.2301]        0.0001      0.007      0.020      0.984      -0.013       0.013
# C(product_id)[T.2314]        0.0078      0.007      1.169      0.242      -0.005       0.021
# C(product_id)[T.2324]        0.0379      0.007      5.655      0.000       0.025       0.051
# C(product_id)[T.2341]        0.0914      0.007     13.640      0.000       0.078       0.105
# C(product_id)[T.2345]        0.0200      0.007      2.990      0.003       0.007       0.033
# C(product_id)[T.2348]        0.0088      0.007      1.306      0.192      -0.004       0.022
# C(product_id)[T.2349]       -0.0081      0.007     -1.213      0.225      -0.021       0.005
# C(product_id)[T.2350]        0.0962      0.007     14.351      0.000       0.083       0.109
# C(product_id)[T.2353]       -0.0064      0.007     -0.951      0.342      -0.020       0.007
# C(product_id)[T.2358]       -0.0015      0.007     -0.229      0.819      -0.015       0.012
# C(product_id)[T.2362]        0.0733      0.007     10.932      0.000       0.060       0.086
# C(product_id)[T.2370]       -0.0167      0.007     -2.490      0.013      -0.030      -0.004
# C(product_id)[T.2371]        0.0024      0.007      0.357      0.721      -0.011       0.016
# C(product_id)[T.2373]        0.0082      0.007      1.219      0.223      -0.005       0.021
# C(product_id)[T.2420]        0.0402      0.007      5.992      0.000       0.027       0.053
# C(product_id)[T.2422]       -0.0020      0.007     -0.302      0.763      -0.015       0.011
# C(product_id)[T.2423]       -0.0537      0.007     -8.017      0.000      -0.067      -0.041
# C(product_id)[T.2435]       -0.0146      0.007     -2.180      0.029      -0.028      -0.001
# C(product_id)[T.2463]       -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.2491]        0.0015      0.007      0.230      0.818      -0.012       0.015
# C(product_id)[T.2493]       -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.2512]        0.0629      0.007      9.387      0.000       0.050       0.076
# C(product_id)[T.2525]        0.0527      0.007      7.861      0.000       0.040       0.066
# C(product_id)[T.2529]        0.0935      0.007     13.958      0.000       0.080       0.107
# C(product_id)[T.2563]       -0.0095      0.007     -1.415      0.157      -0.023       0.004
# C(product_id)[T.2565]        0.0139      0.007      2.074      0.038       0.001       0.027
# C(product_id)[T.2571]      1.17e+08   4.43e+08      0.264      0.792   -7.52e+08    9.86e+08
# C(product_id)[T.2579]        0.0163      0.007      2.439      0.015       0.003       0.029
# C(product_id)[T.2593]        0.0494      0.007      7.367      0.000       0.036       0.063
# C(product_id)[T.2595]        0.0824      0.007     12.290      0.000       0.069       0.095
# C(product_id)[T.2602]        0.1494      0.007     22.295      0.000       0.136       0.163
# C(product_id)[T.2607]       -0.0062      0.007     -0.932      0.351      -0.019       0.007
# C(product_id)[T.2611]       -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.2616]        0.0252      0.007      3.756      0.000       0.012       0.038
# C(product_id)[T.2631]       -0.0576      0.007     -8.599      0.000      -0.071      -0.044
# C(product_id)[T.2632]       -0.0090      0.007     -1.343      0.179      -0.022       0.004
# C(product_id)[T.2668]      1.17e+08   4.43e+08      0.264      0.792   -7.52e+08    9.86e+08
# C(product_id)[T.2669]       -0.0091      0.007     -1.361      0.174      -0.022       0.004
# C(product_id)[T.2677]        0.0143      0.007      2.133      0.033       0.001       0.027
# C(product_id)[T.2720]        0.0104      0.007      1.550      0.121      -0.003       0.024
# C(product_id)[T.2735]        0.0487      0.007      7.266      0.000       0.036       0.062
# C(product_id)[T.2736]       -0.0206      0.007     -3.081      0.002      -0.034      -0.008
# C(product_id)[T.2761]        0.0017      0.007      0.251      0.801      -0.011       0.015
# C(product_id)[T.2766]        0.2707      0.007     40.394      0.000       0.258       0.284
# C(product_id)[T.2773]        0.1317      0.007     19.658      0.000       0.119       0.145
# C(product_id)[T.2780]        0.1195      0.007     17.831      0.000       0.106       0.133
# C(product_id)[T.2785]        0.0119      0.007      1.778      0.075      -0.001       0.025
# C(product_id)[T.2789]        0.0088      0.007      1.306      0.191      -0.004       0.022
# C(product_id)[T.2795]        0.0955      0.007     14.249      0.000       0.082       0.109
# C(product_id)[T.2805]        0.0265      0.007      3.947      0.000       0.013       0.040
# C(product_id)[T.2808]        0.0595      0.007      8.879      0.000       0.046       0.073
# C(product_id)[T.2809]        0.0245      0.007      3.661      0.000       0.011       0.038
# C(product_id)[T.2831]        0.0368      0.007      5.491      0.000       0.024       0.050
# C(product_id)[T.2852]        0.0281      0.007      4.198      0.000       0.015       0.041
# C(product_id)[T.2862]       -0.0576      0.007     -8.598      0.000      -0.071      -0.044
# C(product_id)[T.2878]       -0.0304      0.007     -4.542      0.000      -0.044      -0.017
# C(product_id)[T.2882]        0.0038      0.007      0.570      0.569      -0.009       0.017
# C(product_id)[T.2891]        0.1946      0.007     29.040      0.000       0.181       0.208
# C(product_id)[T.2898]        0.0016      0.007      0.241      0.810      -0.012       0.015
# C(product_id)[T.2927]       -0.0101      0.007     -1.512      0.131      -0.023       0.003
# C(product_id)[T.2939]        0.0818      0.007     12.207      0.000       0.069       0.095
# C(product_id)[T.2945]       -0.0154      0.007     -2.301      0.021      -0.029      -0.002
# C(product_id)[T.2948]       -0.0576      0.007     -8.598      0.000      -0.071      -0.044
# C(product_id)[T.2951]       -0.0110      0.007     -1.643      0.100      -0.024       0.002
# C(product_id)[T.2954]        0.0764      0.007     11.397      0.000       0.063       0.090
# C(product_id)[T.2975]       -0.0218      0.007     -3.254      0.001      -0.035      -0.009
# C(product_id)[T.2979]        0.0134      0.007      1.994      0.046       0.000       0.026
# C(product_id)[T.2987]       -0.0069      0.007     -1.033      0.301      -0.020       0.006
# C(product_id)[T.2998]       -0.0033      0.007     -0.494      0.621      -0.016       0.010
# C(product_id)[T.3019]       -0.0039      0.007     -0.583      0.560      -0.017       0.009
# C(product_id)[T.3033]       -0.0576      0.007     -8.598      0.000      -0.071      -0.044
# C(product_id)[T.3038]        0.0140      0.007      2.091      0.036       0.001       0.027
# C(product_id)[T.3040]        0.0079      0.007      1.174      0.240      -0.005       0.021
# C(product_id)[T.3068]       -0.0065      0.007     -0.963      0.336      -0.020       0.007
# C(product_id)[T.3069]        0.0445      0.007      6.636      0.000       0.031       0.058
# C(product_id)[T.3078]       -0.0067      0.007     -0.993      0.321      -0.020       0.006
# C(product_id)[T.3086]        0.0080      0.007      1.200      0.230      -0.005       0.021
# C(product_id)[T.3103]        0.0410      0.007      6.119      0.000       0.028       0.054
# C(product_id)[T.3104]        0.0715      0.007     10.664      0.000       0.058       0.085
# C(product_id)[T.3109]       -0.0137      0.007     -2.051      0.040      -0.027      -0.001
# C(product_id)[T.3143]        0.0365      0.007      5.445      0.000       0.023       0.050
# C(product_id)[T.3193]       -0.0177      0.007     -2.635      0.008      -0.031      -0.005
# C(product_id)[T.3208]        0.1423      0.007     21.235      0.000       0.129       0.155
# C(product_id)[T.3250]       -0.0173      0.007     -2.575      0.010      -0.030      -0.004
# C(product_id)[T.3269]       -0.0035      0.007     -0.519      0.604      -0.017       0.010
# C(product_id)[T.3281]        0.0107      0.007      1.599      0.110      -0.002       0.024
# C(product_id)[T.3287]       -0.0576      0.007     -8.598      0.000      -0.071      -0.044
# C(product_id)[T.3304]       -0.0243      0.007     -3.627      0.000      -0.037      -0.011
# C(product_id)[T.3312]        0.0637      0.007      9.511      0.000       0.051       0.077
# C(product_id)[T.3314]        0.0252      0.007      3.763      0.000       0.012       0.038
# C(product_id)[T.3318]        0.0125      0.007      1.866      0.062      -0.001       0.026
# C(product_id)[T.3322]        0.1012      0.007     15.102      0.000       0.088       0.114
# C(product_id)[T.3326]       -0.0576      0.007     -8.598      0.000      -0.071      -0.044
# C(product_id)[T.3335]       -0.0269      0.007     -4.009      0.000      -0.040      -0.014
# C(product_id)[T.3341]        0.0288      0.007      4.293      0.000       0.016       0.042
# C(product_id)[T.3351]        0.0010      0.007      0.152      0.879      -0.012       0.014
# C(product_id)[T.3356]       -0.0022      0.007     -0.335      0.738      -0.015       0.011
# C(product_id)[T.3357]        0.0119      0.007      1.783      0.075      -0.001       0.025
# C(product_id)[T.3361]       -0.0173      0.007     -2.582      0.010      -0.030      -0.004
# C(product_id)[T.3376]        0.0491      0.007      7.324      0.000       0.036       0.062
# C(product_id)[T.3377]       -0.0576      0.007     -8.598      0.000      -0.071      -0.044
# C(product_id)[T.3385]       -0.0046      0.007     -0.682      0.495      -0.018       0.009
# C(product_id)[T.3386]        0.0737      0.007     10.994      0.000       0.061       0.087
# C(product_id)[T.3387]        0.0299      0.007      4.455      0.000       0.017       0.043
# C(product_id)[T.3388]        0.3432      0.007     51.213      0.000       0.330       0.356
# C(product_id)[T.3391]       -0.0006      0.007     -0.086      0.932      -0.014       0.013
# C(product_id)[T.3397]        0.0104      0.007      1.548      0.122      -0.003       0.024
# C(product_id)[T.3398]       -0.0576      0.007     -8.598      0.000      -0.071      -0.044
# C(product_id)[T.3409]       -0.0165      0.007     -2.457      0.014      -0.030      -0.003
# C(product_id)[T.3419]        0.0084      0.007      1.251      0.211      -0.005       0.022
# C(product_id)[T.3439]       -0.0485      0.007     -7.235      0.000      -0.062      -0.035
# C(product_id)[T.3444]       -0.0474      0.007     -7.068      0.000      -0.060      -0.034
# C(product_id)[T.3445]        0.0203      0.007      3.030      0.002       0.007       0.033
# C(product_id)[T.3472]        0.0276      0.007      4.111      0.000       0.014       0.041
# C(product_id)[T.3494]        0.0286      0.007      4.274      0.000       0.016       0.042
# C(product_id)[T.3505]        0.0080      0.007      1.190      0.234      -0.005       0.021
# C(product_id)[T.3523]        0.2446      0.007     36.498      0.000       0.231       0.258
# C(product_id)[T.3527]       -0.0094      0.007     -1.404      0.160      -0.023       0.004
# C(product_id)[T.3537]        0.1177      0.007     17.567      0.000       0.105       0.131
# C(product_id)[T.3546]       -0.0002      0.007     -0.029      0.977      -0.013       0.013
# C(product_id)[T.3559]        0.0890      0.007     13.287      0.000       0.076       0.102
# C(product_id)[T.3562]       -0.0576      0.007     -8.598      0.000      -0.071      -0.044
# C(product_id)[T.3563]       -0.0093      0.007     -1.390      0.164      -0.022       0.004
# C(product_id)[T.3583]       -0.0043      0.007     -0.634      0.526      -0.017       0.009
# C(product_id)[T.3584]        0.0099      0.007      1.477      0.140      -0.003       0.023
# C(product_id)[T.3590]        0.0322      0.007      4.812      0.000       0.019       0.045
# C(product_id)[T.3599]        0.0422      0.007      6.299      0.000       0.029       0.055
# C(product_id)[T.3629]       -0.0087      0.007     -1.305      0.192      -0.022       0.004
# C(product_id)[T.3651]       -0.0045      0.007     -0.669      0.504      -0.018       0.009
# C(product_id)[T.3667]        0.0133      0.007      1.980      0.048       0.000       0.026
# C(product_id)[T.3676]        0.0168      0.007      2.507      0.012       0.004       0.030
# C(product_id)[T.3700]       -0.0576      0.007     -8.598      0.000      -0.071      -0.044
# C(product_id)[T.3705]       -0.0211      0.007     -3.143      0.002      -0.034      -0.008
# C(product_id)[T.3709]        0.0072      0.007      1.082      0.279      -0.006       0.020
# C(product_id)[T.3724]       -0.0301      0.007     -4.493      0.000      -0.043      -0.017
# C(product_id)[T.3754]       -0.0197      0.007     -2.938      0.003      -0.033      -0.007
# C(product_id)[T.3755]       -0.0480      0.007     -7.165      0.000      -0.061      -0.035
# C(product_id)[T.3771]        0.0282      0.007      4.215      0.000       0.015       0.041
# C(product_id)[T.3792]       -0.0131      0.007     -1.952      0.051      -0.026    5.26e-05
# C(product_id)[T.3794]        0.0136      0.007      2.032      0.042       0.000       0.027
# C(product_id)[T.3798]        0.0050      0.007      0.750      0.453      -0.008       0.018
# C(product_id)[T.3854]        0.0152      0.007      2.271      0.023       0.002       0.028
# C(product_id)[T.3862]       -0.0129      0.007     -1.927      0.054      -0.026       0.000
# C(product_id)[T.3884]        0.0018      0.007      0.266      0.790      -0.011       0.015
# C(product_id)[T.3897]        0.0600      0.007      8.949      0.000       0.047       0.073
# C(product_id)[T.3904]        0.0762      0.007     11.365      0.000       0.063       0.089
# C(product_id)[T.3906]     -4.25e-06      0.007     -0.001      0.999      -0.013       0.013
# C(product_id)[T.3911]        0.1882      0.007     28.081      0.000       0.175       0.201
# C(product_id)[T.3930]       -0.0041      0.007     -0.608      0.543      -0.017       0.009
# C(product_id)[T.3952]        0.0032      0.007      0.484      0.628      -0.010       0.016
# C(product_id)[T.3969]       -0.0407      0.007     -6.066      0.000      -0.054      -0.028
# C(product_id)[T.3986]       -0.0576      0.007     -8.598      0.000      -0.071      -0.044
# C(product_id)[T.3990]        0.0225      0.007      3.359      0.001       0.009       0.036
# C(product_id)[T.4009]        0.1429      0.007     21.326      0.000       0.130       0.156
# C(product_id)[T.4011]       -0.0576      0.007     -8.598      0.000      -0.071      -0.044
# C(product_id)[T.4018]        0.0069      0.007      1.025      0.305      -0.006       0.020
# C(product_id)[T.4032]       -0.0069      0.007     -1.026      0.305      -0.020       0.006
# C(product_id)[T.4038]        0.0107      0.007      1.596      0.110      -0.002       0.024
# C(product_id)[T.4057]       -0.0059      0.007     -0.886      0.375      -0.019       0.007
# C(product_id)[T.4060]        0.0483      0.007      7.200      0.000       0.035       0.061
# C(product_id)[T.4062]        0.0340      0.007      5.071      0.000       0.021       0.047
# C(product_id)[T.4070]        0.0006      0.007      0.095      0.924      -0.012       0.014
# C(product_id)[T.4101]        0.0533      0.007      7.946      0.000       0.040       0.066
# C(product_id)[T.4106]        0.0046      0.007      0.691      0.490      -0.009       0.018
# C(product_id)[T.4118]       -0.0071      0.007     -1.052      0.293      -0.020       0.006
# C(product_id)[T.4123]       -0.0413      0.007     -6.158      0.000      -0.054      -0.028
# C(product_id)[T.4125]        0.0088      0.007      1.318      0.188      -0.004       0.022
# C(product_id)[T.4129]       -0.0576      0.007     -8.598      0.000      -0.071      -0.044
# C(product_id)[T.4132]        0.0698      0.007     10.419      0.000       0.057       0.083
# C(product_id)[T.4144]      1.17e+08   4.43e+08      0.264      0.792   -7.52e+08    9.86e+08
# C(product_id)[T.4158]       -0.0091      0.007     -1.355      0.175      -0.022       0.004
# C(product_id)[T.4174]        0.2716      0.007     40.537      0.000       0.259       0.285
# C(product_id)[T.4183]        0.0166      0.007      2.471      0.013       0.003       0.030
# C(product_id)[T.4194]        0.0463      0.007      6.909      0.000       0.033       0.059
# C(product_id)[T.4200]        0.0247      0.007      3.692      0.000       0.012       0.038
# C(product_id)[T.4201]       -0.0052      0.007     -0.770      0.441      -0.018       0.008
# C(product_id)[T.4202]        0.1501      0.007     22.394      0.000       0.137       0.163
# C(product_id)[T.4223]        0.0300      0.007      4.476      0.000       0.017       0.043
# C(product_id)[T.4248]        0.1335      0.007     19.924      0.000       0.120       0.147
# C(product_id)[T.4280]        0.0576      0.007      8.589      0.000       0.044       0.071
# C(product_id)[T.4291]        0.2555      0.007     38.135      0.000       0.242       0.269
# C(product_id)[T.4293]        0.0133      0.007      1.986      0.047       0.000       0.026
# C(product_id)[T.4302]        0.0906      0.007     13.513      0.000       0.077       0.104
# C(product_id)[T.4317]       -0.0576      0.007     -8.598      0.000      -0.071      -0.044
# C(product_id)[T.4333]        0.0221      0.007      3.299      0.001       0.009       0.035
# C(product_id)[T.4341]        0.0804      0.007     11.993      0.000       0.067       0.093
# C(product_id)[T.4346]       -0.0012      0.007     -0.181      0.856      -0.014       0.012
# C(product_id)[T.4347]       -0.0145      0.007     -2.164      0.030      -0.028      -0.001
# C(product_id)[T.4351]       -0.0133      0.007     -1.984      0.047      -0.026      -0.000
# C(product_id)[T.4361]       -0.0187      0.007     -2.796      0.005      -0.032      -0.006
# C(month)[T.2]                0.0035      0.001      4.222      0.000       0.002       0.005
# C(month)[T.3]                0.0032      0.001      3.985      0.000       0.002       0.005
# C(month)[T.4]               -0.0088      0.001    -10.733      0.000      -0.010      -0.007
# C(month)[T.5]               -0.0131      0.001    -16.046      0.000      -0.015      -0.012
# C(month)[T.6]               -0.0089      0.001    -10.835      0.000      -0.011      -0.007
# C(day_of_week)[T.1]         -0.0048      0.001     -5.383      0.000      -0.007      -0.003
# C(day_of_week)[T.2]         -0.0036      0.001     -4.098      0.000      -0.005      -0.002
# C(day_of_week)[T.3]         -0.0031      0.001     -3.535      0.000      -0.005      -0.001
# C(day_of_week)[T.4]          0.0084      0.001      9.346      0.000       0.007       0.010
# C(day_of_week)[T.5]          0.0251      0.001     28.355      0.000       0.023       0.027
# C(day_of_week)[T.6]          0.0382      0.001     43.138      0.000       0.036       0.040
# C(hour)[T.1]                -0.0213      0.002    -12.935      0.000      -0.024      -0.018
# C(hour)[T.2]                -0.0226      0.002    -13.767      0.000      -0.026      -0.019
# C(hour)[T.3]                -0.0278      0.002    -16.886      0.000      -0.031      -0.025
# C(hour)[T.4]                -0.0332      0.002    -20.205      0.000      -0.036      -0.030
# C(hour)[T.5]                -0.0332      0.002    -20.204      0.000      -0.036      -0.030
# C(hour)[T.6]                -0.0184      0.002    -11.207      0.000      -0.022      -0.015
# C(hour)[T.7]                 0.0047      0.002      2.859      0.004       0.001       0.008
# C(hour)[T.8]                 0.0064      0.002      3.878      0.000       0.003       0.010
# C(hour)[T.9]                 0.0283      0.002     17.225      0.000       0.025       0.032
# C(hour)[T.10]                0.0394      0.002     23.962      0.000       0.036       0.043
# C(hour)[T.11]                0.0588      0.002     35.779      0.000       0.056       0.062
# C(hour)[T.12]                0.0733      0.002     44.611      0.000       0.070       0.077
# C(hour)[T.13]                0.0854      0.002     51.971      0.000       0.082       0.089
# C(hour)[T.14]                0.0815      0.002     49.568      0.000       0.078       0.085
# C(hour)[T.15]                0.0731      0.002     44.461      0.000       0.070       0.076
# C(hour)[T.16]                0.0863      0.002     52.511      0.000       0.083       0.090
# C(hour)[T.17]                0.1063      0.002     64.665      0.000       0.103       0.109
# C(hour)[T.18]                0.1418      0.002     86.282      0.000       0.139       0.145
# C(hour)[T.19]                0.1675      0.002    101.905      0.000       0.164       0.171
# C(hour)[T.20]                0.1838      0.002    111.814      0.000       0.181       0.187
# C(hour)[T.21]                0.1744      0.002    106.136      0.000       0.171       0.178
# C(hour)[T.22]                0.1295      0.002     78.831      0.000       0.126       0.133
# C(hour)[T.23]                0.0849      0.002     51.635      0.000       0.082       0.088
# stockout_dum                -0.0015      0.001     -1.351      0.177      -0.004       0.001
# com_dum                   -1.17e+08   4.43e+08     -0.264      0.792   -9.86e+08    7.52e+08
# stockout_com_interaction    -0.0326      0.008     -4.062      0.000      -0.048      -0.017
# ==============================================================================
# Omnibus:                  1331709.637   Durbin-Watson:                   1.770
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         32483341.194
# Skew:                           3.549   Prob(JB):                         0.00
# Kurtosis:                      22.985   Cond. No.                     6.05e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.2e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Concatenate the dummy variables with the original DataFrame
df_without_dummies = df_regression_2022.copy()

# Log-transform the dependent variable
df_without_dummies['log_hourly_sales'] = np.log(1 + df_without_dummies['hourly_sales'])

df_without_dummies = df_without_dummies.drop(['product_id','month','day','hour','day_of_week','hourly_sales'], axis=1)

# Create the design matrix by specifying the formula with interaction terms
formula_without_dummies = 'log_hourly_sales ~ stockout_dum + com_dum + stockout_com_interaction'

# Fit the linear regression model
results_without_dummies = smf.ols(formula=formula_without_dummies, data=df_without_dummies).fit()
#results_without_dummies = smf.wls(formula = formula_without_dummies, data=df_without_dummies, weights=1/np.square(residuals)).fit(cov_type='HC3')


# Get the summary of the regression results
print(results_without_dummies.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       log_hourly_sales   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1178.
# Date:                Mon, 03 Jul 2023   Prob (F-statistic):               0.00
# Time:                        12:39:10   Log-Likelihood:            -5.9787e+05
# No. Observations:             1733256   AIC:                         1.196e+06
# Df Residuals:                 1733252   BIC:                         1.196e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.0878      0.000    326.292      0.000       0.087       0.088
# stockout_dum                 0.0073      0.001      6.266      0.000       0.005       0.010
# com_dum                      0.1184      0.002     58.300      0.000       0.114       0.122
# stockout_com_interaction    -0.0326      0.009     -3.713      0.000      -0.050      -0.015
# ==============================================================================
# Omnibus:                  1673788.168   Durbin-Watson:                   1.485
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         66945063.838
# Skew:                           4.874   Prob(JB):                         0.00
# Kurtosis:                      31.844   Cond. No.                         34.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from tabulate import tabulate

# Function to determine significance level
def get_significance(p_value):
    if p_value < 0.001:
        return '***'
    elif p_value < 0.01:
        return '**'
    elif p_value < 0.05:
        return '*'
    else:
        return ''

# Create the summary table in a list format
summary_table_list = []

# Add the coefficient, standard error, and significance level rows
summary_table_list.append(['stockout_dum', '{:.4f} ({:.4f}){}'.format(results.params['stockout_dum'], results.bse['stockout_dum'], get_significance(results.pvalues['stockout_dum'])), '{:.4f} ({:.4f}){}'.format(results_without_dummies.params['stockout_dum'], results_without_dummies.bse['stockout_dum'], get_significance(results_without_dummies.pvalues['stockout_dum']))])
summary_table_list.append(['com_dum', '{:.4f} ({:.4f}){}'.format(results.params['com_dum'], results.bse['com_dum'], get_significance(results.pvalues['com_dum'])), '{:.4f} ({:.4f}){}'.format(results_without_dummies.params['com_dum'], results_without_dummies.bse['com_dum'], get_significance(results_without_dummies.pvalues['com_dum']))])
summary_table_list.append(['stockout_com_interaction', '{:.4f} ({:.4f}){}'.format(results.params['stockout_com_interaction'], results.bse['stockout_com_interaction'], get_significance(results.pvalues['stockout_com_interaction'])), '{:.4f} ({:.4f}){}'.format(results_without_dummies.params['stockout_com_interaction'], results_without_dummies.bse['stockout_com_interaction'], get_significance(results_without_dummies.pvalues['stockout_com_interaction']))])

# Add the inclusion information
summary_table_list.append(['month', 'yes', 'no'])
summary_table_list.append(['day', 'yes', 'no'])
summary_table_list.append(['day_of_week', 'yes', 'no'])
summary_table_list.append(['hour', 'yes', 'no'])

summary_table_list.append(['R-squared', '{:.4f}'.format(results.rsquared), '{:.4f}'.format(results_without_dummies.rsquared)])

summary_table_list.append(['No. Observations', '{:,}'.format(results.nobs), '{:,}'.format(results_without_dummies.nobs)])

# Create the table headers
headers = ['Variable', 'Model_with_FixedEffects', 'Model_without_FixedEffects']

# Print the summary table using tabulate
print(tabulate(summary_table_list, headers, tablefmt="grid"))

# %%
filename = 'summary_table_3834.csv'

# Save the list as a CSV file
with open(filename, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(summary_table_list)

# %%
df_regression = merged_df.copy()
df_regression = df_regression[df_regression['product_id']!=3834]
df_regression_2022 = df_regression[(df_regression['year']==2022)]
df_regression_2022 = df_regression_2022[df_regression_2022['month'].isin([1,2,3,4,5,6])]
df_regression_2022 = df_regression_2022.drop(['timestamp','instock_fraction','year'], axis=1)

# %%
month_dummies = pd.get_dummies(df_regression_2022['month'], prefix='month', drop_first=True)
day_of_week_dummies = pd.get_dummies(df_regression_2022['day_of_week'], prefix='day', drop_first=True)
hour_dummies = pd.get_dummies(df_regression_2022['hour'], prefix='hour', drop_first=True)
product_id_dummies = pd.get_dummies(df_regression_2022['product_id'], prefix='product_id', drop_first=True)

# Concatenate the dummy variables with the original DataFrame
df_with_dummies = pd.concat([df_regression_2022, month_dummies, day_of_week_dummies, hour_dummies, product_id_dummies], axis=1)

# Log-transform the dependent variable
df_with_dummies['log_hourly_sales'] = np.log(1 + df_with_dummies['hourly_sales'])

# Create the design matrix by specifying the formula with interaction terms
formula = 'log_hourly_sales ~ stockout_dum + com_dum + stockout_com_interaction + C(product_id) + C(month) + C(day_of_week) + C(hour)'

# Add product-by-month fixed effects to the formula
product_month_interaction_terms = ' + C(product_id):C(month)'
formula_with_product_month_effects = formula + product_month_interaction_terms

# %%
# Fit the regression model with product-by-month fixed effects
model_with_product_month_effects = smf.ols(formula_with_product_month_effects, data=df_with_dummies).fit()

# %%
# Get the summary of the regression results
print(model_with_product_month_effects.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       log_hourly_sales   R-squared:                       0.179
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     153.0
# Date:                Mon, 03 Jul 2023   Prob (F-statistic):               0.00
# Time:                        13:09:13   Log-Likelihood:            -2.3610e+05
# No. Observations:              861840   AIC:                         4.747e+05
# Df Residuals:                  860612   BIC:                         4.890e+05
# Df Model:                        1227
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -0.0151      0.012     -1.279      0.201      -0.038       0.008
# C(product_id)[T.3]                      0.0141      0.017      0.855      0.392      -0.018       0.047
# C(product_id)[T.23]                    -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.43]                    -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.45]                    -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.54]                     0.0017      0.017      0.105      0.916      -0.031       0.034
# C(product_id)[T.59]                     0.0255      0.017      1.542      0.123      -0.007       0.058
# C(product_id)[T.78]                     0.0416      0.017      2.517      0.012       0.009       0.074
# C(product_id)[T.85]                     0.0081      0.017      0.489      0.625      -0.024       0.040
# C(product_id)[T.86]                    -0.0364      0.017     -2.203      0.028      -0.069      -0.004
# C(product_id)[T.89]                     0.0310      0.017      1.876      0.061      -0.001       0.063
# C(product_id)[T.125]                    0.0008      0.017      0.045      0.964      -0.032       0.033
# C(product_id)[T.133]                    0.0270      0.017      1.635      0.102      -0.005       0.059
# C(product_id)[T.139]                    0.0964      0.017      5.836      0.000       0.064       0.129
# C(product_id)[T.147]                   -0.0131      0.017     -0.795      0.427      -0.046       0.019
# C(product_id)[T.161]                    0.0238      0.017      1.439      0.150      -0.009       0.056
# C(product_id)[T.174]                    0.1043      0.017      6.312      0.000       0.072       0.137
# C(product_id)[T.204]                   -0.0208      0.017     -1.261      0.207      -0.053       0.012
# C(product_id)[T.206]                   -0.0107      0.017     -0.648      0.517      -0.043       0.022
# C(product_id)[T.210]                   -0.0114      0.017     -0.691      0.490      -0.044       0.021
# C(product_id)[T.218]                   -0.0078      0.017     -0.469      0.639      -0.040       0.025
# C(product_id)[T.245]                    0.0060      0.017      0.363      0.716      -0.026       0.038
# C(product_id)[T.246]                    0.0406      0.017      2.457      0.014       0.008       0.073
# C(product_id)[T.249]                   -0.0214      0.017     -1.296      0.195      -0.054       0.011
# C(product_id)[T.252]                 -1.42e+08   4.27e+08     -0.332      0.740   -9.79e+08    6.95e+08
# C(product_id)[T.270]                    0.0078      0.017      0.471      0.637      -0.025       0.040
# C(product_id)[T.273]                   -0.0019      0.017     -0.116      0.908      -0.034       0.030
# C(product_id)[T.274]                    0.1370      0.017      8.289      0.000       0.105       0.169
# C(product_id)[T.275]                    0.1794      0.017     10.855      0.000       0.147       0.212
# C(product_id)[T.278]                    0.0216      0.017      1.309      0.191      -0.011       0.054
# C(product_id)[T.288]                    0.0083      0.017      0.504      0.614      -0.024       0.041
# C(product_id)[T.291]                    0.0152      0.017      0.920      0.358      -0.017       0.048
# C(product_id)[T.299]                    0.0017      0.017      0.105      0.916      -0.031       0.034
# C(product_id)[T.314]                   -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.338]                   -0.0150      0.017     -0.906      0.365      -0.047       0.017
# C(product_id)[T.347]                    0.0480      0.017      2.907      0.004       0.016       0.080
# C(product_id)[T.355]                    0.0260      0.017      1.576      0.115      -0.006       0.058
# C(product_id)[T.362]                    0.0845      0.017      5.113      0.000       0.052       0.117
# C(product_id)[T.375]                   -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.377]                   -0.0167      0.017     -1.012      0.312      -0.049       0.016
# C(product_id)[T.378]                   -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.387]                    0.0072      0.017      0.436      0.663      -0.025       0.040
# C(product_id)[T.397]                   -0.0253      0.017     -1.531      0.126      -0.058       0.007
# C(product_id)[T.404]                   -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.407]                   -0.0297      0.017     -1.799      0.072      -0.062       0.003
# C(product_id)[T.418]                   -0.0138      0.017     -0.835      0.404      -0.046       0.019
# C(product_id)[T.429]                   -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.430]                   -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.433]                    0.0138      0.017      0.833      0.405      -0.019       0.046
# C(product_id)[T.441]                    0.0134      0.017      0.813      0.416      -0.019       0.046
# C(product_id)[T.447]                    0.0225      0.017      1.364      0.173      -0.010       0.055
# C(product_id)[T.460]                   -0.0083      0.017     -0.502      0.616      -0.041       0.024
# C(product_id)[T.462]                    0.0468      0.017      2.835      0.005       0.014       0.079
# C(product_id)[T.475]                    0.1024      0.017      6.200      0.000       0.070       0.135
# C(product_id)[T.493]                    0.0276      0.017      1.670      0.095      -0.005       0.060
# C(product_id)[T.495]                    0.2461      0.017     14.895      0.000       0.214       0.278
# C(product_id)[T.496]                    0.0518      0.017      3.134      0.002       0.019       0.084
# C(product_id)[T.515]                   -0.0156      0.017     -0.944      0.345      -0.048       0.017
# C(product_id)[T.523]                 -1.42e+08   4.27e+08     -0.332      0.740   -9.79e+08    6.95e+08
# C(product_id)[T.528]                    0.5448      0.017     32.972      0.000       0.512       0.577
# C(product_id)[T.530]                    0.1574      0.017      9.524      0.000       0.125       0.190
# C(product_id)[T.537]                    0.0481      0.017      2.910      0.004       0.016       0.080
# C(product_id)[T.560]                    0.0657      0.017      3.976      0.000       0.033       0.098
# C(product_id)[T.561]                    0.0328      0.017      1.987      0.047       0.000       0.065
# C(product_id)[T.567]                    0.0202      0.017      1.223      0.221      -0.012       0.053
# C(product_id)[T.580]                   -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.587]                   -0.0092      0.017     -0.558      0.577      -0.042       0.023
# C(product_id)[T.594]                   -0.0342      0.017     -2.071      0.038      -0.067      -0.002
# C(product_id)[T.602]                   -0.0126      0.017     -0.761      0.447      -0.045       0.020
# C(product_id)[T.604]                    0.0106      0.017      0.641      0.521      -0.022       0.043
# C(product_id)[T.623]                    0.0547      0.017      3.313      0.001       0.022       0.087
# C(product_id)[T.629]                   -0.0140      0.017     -0.845      0.398      -0.046       0.018
# C(product_id)[T.646]                   -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.650]                    0.0410      0.017      2.482      0.013       0.009       0.073
# C(product_id)[T.667]                    1.1784      0.017     71.316      0.000       1.146       1.211
# C(product_id)[T.687]                   -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.688]                    0.1569      0.017      9.493      0.000       0.124       0.189
# C(product_id)[T.695]                    0.0101      0.017      0.613      0.540      -0.022       0.043
# C(product_id)[T.699]                   -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.703]                    0.0127      0.017      0.766      0.444      -0.020       0.045
# C(product_id)[T.708]                   -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.716]                   -0.0104      0.017     -0.627      0.531      -0.043       0.022
# C(product_id)[T.719]                    0.8014      0.017     48.504      0.000       0.769       0.834
# C(product_id)[T.735]                    0.2322      0.017     14.052      0.000       0.200       0.265
# C(product_id)[T.739]                   -0.0411      0.017     -2.487      0.013      -0.073      -0.009
# C(product_id)[T.752]                 -1.42e+08   4.27e+08     -0.332      0.740   -9.79e+08    6.95e+08
# C(product_id)[T.777]                   -0.0060      0.017     -0.361      0.718      -0.038       0.026
# C(product_id)[T.780]                   -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.789]                    0.0211      0.017      1.274      0.203      -0.011       0.053
# C(product_id)[T.820]                   -0.0008      0.017     -0.050      0.960      -0.033       0.032
# C(product_id)[T.821]                    0.0047      0.017      0.283      0.777      -0.028       0.037
# C(product_id)[T.826]                    0.0398      0.017      2.408      0.016       0.007       0.072
# C(product_id)[T.871]                   -0.0205      0.017     -1.242      0.214      -0.053       0.012
# C(product_id)[T.880]                    0.0541      0.017      3.272      0.001       0.022       0.086
# C(product_id)[T.887]                   -0.0092      0.017     -0.559      0.576      -0.042       0.023
# C(product_id)[T.900]                    0.0002      0.017      0.015      0.988      -0.032       0.033
# C(product_id)[T.912]                    0.1047      0.017      6.336      0.000       0.072       0.137
# C(product_id)[T.928]                   -0.0039      0.017     -0.238      0.812      -0.036       0.028
# C(product_id)[T.944]                    0.0511      0.017      3.093      0.002       0.019       0.083
# C(product_id)[T.962]                    0.0455      0.017      2.755      0.006       0.013       0.078
# C(product_id)[T.971]                    0.0367      0.017      2.224      0.026       0.004       0.069
# C(product_id)[T.982]                    0.0064      0.017      0.385      0.700      -0.026       0.039
# C(product_id)[T.994]                   -0.0320      0.017     -1.935      0.053      -0.064       0.000
# C(product_id)[T.1001]                   0.0568      0.017      3.435      0.001       0.024       0.089
# C(product_id)[T.1031]                   0.0287      0.017      1.735      0.083      -0.004       0.061
# C(product_id)[T.1061]                   0.0354      0.017      2.139      0.032       0.003       0.068
# C(product_id)[T.1064]                   0.0105      0.017      0.635      0.525      -0.022       0.043
# C(product_id)[T.1084]                   0.0040      0.017      0.242      0.809      -0.028       0.036
# C(product_id)[T.1091]                  -0.0135      0.017     -0.817      0.414      -0.046       0.019
# C(product_id)[T.1093]                   0.0661      0.017      4.003      0.000       0.034       0.099
# C(product_id)[T.1094]                   0.1073      0.017      6.491      0.000       0.075       0.140
# C(product_id)[T.1114]                  -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.1115]                   0.0246      0.017      1.489      0.136      -0.008       0.057
# C(product_id)[T.1124]                   0.0635      0.017      3.841      0.000       0.031       0.096
# C(product_id)[T.1149]                   0.1798      0.017     10.885      0.000       0.147       0.212
# C(product_id)[T.1151]                   0.1845      0.017     11.167      0.000       0.152       0.217
# C(product_id)[T.1161]                  -0.0021      0.017     -0.125      0.900      -0.034       0.030
# C(product_id)[T.1163]                  -0.0072      0.017     -0.435      0.664      -0.040       0.025
# C(product_id)[T.1165]                  -0.0008      0.017     -0.046      0.963      -0.033       0.032
# C(product_id)[T.1197]                  -0.0095      0.017     -0.572      0.567      -0.042       0.023
# C(product_id)[T.1211]                   0.0482      0.017      2.915      0.004       0.016       0.081
# C(product_id)[T.1216]                  -0.0061      0.017     -0.370      0.711      -0.039       0.026
# C(product_id)[T.1219]                   0.0162      0.017      0.983      0.326      -0.016       0.049
# C(product_id)[T.1262]                   0.0185      0.017      1.119      0.263      -0.014       0.051
# C(product_id)[T.1279]                   0.7714      0.017     46.685      0.000       0.739       0.804
# C(product_id)[T.1280]                   0.8094      0.017     48.988      0.000       0.777       0.842
# C(product_id)[T.1288]                  -0.0111      0.017     -0.672      0.501      -0.043       0.021
# C(product_id)[T.1291]                   0.0130      0.017      0.788      0.431      -0.019       0.045
# C(product_id)[T.1304]                   0.0220      0.017      1.332      0.183      -0.010       0.054
# C(product_id)[T.1305]                   0.0020      0.017      0.119      0.905      -0.030       0.034
# C(product_id)[T.1307]                   0.1714      0.017     10.372      0.000       0.139       0.204
# C(product_id)[T.1309]                   0.0350      0.017      2.118      0.034       0.003       0.067
# C(product_id)[T.1314]                   0.0110      0.017      0.664      0.507      -0.021       0.043
# C(product_id)[T.1336]                   0.1263      0.017      7.644      0.000       0.094       0.159
# C(product_id)[T.1355]                   0.1701      0.017     10.296      0.000       0.138       0.203
# C(product_id)[T.1366]                  -0.0220      0.017     -1.329      0.184      -0.054       0.010
# C(product_id)[T.1369]                   0.0247      0.017      1.495      0.135      -0.008       0.057
# C(product_id)[T.1370]                   0.0935      0.017      5.660      0.000       0.061       0.126
# C(product_id)[T.1384]                  -0.0338      0.017     -2.048      0.041      -0.066      -0.001
# C(product_id)[T.1414]                   0.1621      0.017      9.810      0.000       0.130       0.194
# C(product_id)[T.1454]                   0.0328      0.017      1.987      0.047       0.000       0.065
# C(product_id)[T.1462]                   0.0759      0.017      4.594      0.000       0.044       0.108
# C(product_id)[T.1487]                   0.0128      0.017      0.774      0.439      -0.020       0.045
# C(product_id)[T.1506]                   0.1170      0.017      7.079      0.000       0.085       0.149
# C(product_id)[T.1514]                   0.0031      0.017      0.189      0.850      -0.029       0.036
# C(product_id)[T.1515]                   0.0969      0.017      5.863      0.000       0.064       0.129
# C(product_id)[T.1516]                   0.0385      0.017      2.332      0.020       0.006       0.071
# C(product_id)[T.1517]                  -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.1541]                   0.0891      0.017      5.392      0.000       0.057       0.121
# C(product_id)[T.1542]                   0.0219      0.017      1.327      0.185      -0.010       0.054
# C(product_id)[T.1570]                   0.0645      0.017      3.902      0.000       0.032       0.097
# C(product_id)[T.1574]                   0.0583      0.017      3.526      0.000       0.026       0.091
# C(product_id)[T.1578]                  -0.0175      0.017     -1.060      0.289      -0.050       0.015
# C(product_id)[T.1588]                   0.1497      0.017      9.057      0.000       0.117       0.182
# C(product_id)[T.1610]                -1.42e+08   4.27e+08     -0.332      0.740   -9.79e+08    6.95e+08
# C(product_id)[T.1621]                   0.2115      0.017     12.798      0.000       0.179       0.244
# C(product_id)[T.1652]                   0.0185      0.017      1.118      0.263      -0.014       0.051
# C(product_id)[T.1664]                  -0.0050      0.017     -0.304      0.761      -0.037       0.027
# C(product_id)[T.1669]                   0.1006      0.017      6.086      0.000       0.068       0.133
# C(product_id)[T.1677]                   0.0303      0.017      1.834      0.067      -0.002       0.063
# C(product_id)[T.1689]                  -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.1706]                  -0.0501      0.017     -3.031      0.002      -0.082      -0.018
# C(product_id)[T.1714]                   0.0068      0.017      0.410      0.682      -0.026       0.039
# C(product_id)[T.1715]                   0.0587      0.017      3.550      0.000       0.026       0.091
# C(product_id)[T.1749]                   0.0038      0.017      0.232      0.816      -0.029       0.036
# C(product_id)[T.1764]                   0.1229      0.017      7.441      0.000       0.091       0.155
# C(product_id)[T.1779]                  -0.0394      0.017     -2.386      0.017      -0.072      -0.007
# C(product_id)[T.1816]                   0.0262      0.017      1.585      0.113      -0.006       0.059
# C(product_id)[T.1866]                   0.0047      0.017      0.283      0.777      -0.028       0.037
# C(product_id)[T.1893]                   0.0410      0.017      2.481      0.013       0.009       0.073
# C(product_id)[T.1899]                   0.0620      0.017      3.754      0.000       0.030       0.094
# C(product_id)[T.1904]                   0.1052      0.017      6.366      0.000       0.073       0.138
# C(product_id)[T.1947]                   0.0009      0.017      0.052      0.958      -0.032       0.033
# C(product_id)[T.1948]                   0.2609      0.017     15.791      0.000       0.229       0.293
# C(product_id)[T.1951]                   0.0043      0.017      0.260      0.795      -0.028       0.037
# C(product_id)[T.1960]                  -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.1985]                  -0.0156      0.017     -0.944      0.345      -0.048       0.017
# C(product_id)[T.1990]                  -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.1996]                  -0.0151      0.017     -0.913      0.361      -0.047       0.017
# C(product_id)[T.2004]                   0.0144      0.017      0.872      0.383      -0.018       0.047
# C(product_id)[T.2017]                   0.0082      0.017      0.499      0.618      -0.024       0.041
# C(product_id)[T.2019]                   0.0422      0.017      2.551      0.011       0.010       0.075
# C(product_id)[T.2023]                  -0.0030      0.017     -0.182      0.856      -0.035       0.029
# C(product_id)[T.2033]                  -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.2044]                  -0.0212      0.017     -1.282      0.200      -0.054       0.011
# C(product_id)[T.2046]                  -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.2047]                   0.0704      0.017      4.262      0.000       0.038       0.103
# C(product_id)[T.2071]                   0.0107      0.017      0.650      0.516      -0.022       0.043
# C(product_id)[T.2075]                  -0.0357      0.017     -2.161      0.031      -0.068      -0.003
# C(product_id)[T.2091]                   0.0073      0.017      0.444      0.657      -0.025       0.040
# C(product_id)[T.2099]                   0.0010      0.017      0.062      0.951      -0.031       0.033
# C(product_id)[T.2104]                   0.0815      0.017      4.934      0.000       0.049       0.114
# C(product_id)[T.2126]                   0.1393      0.017      8.430      0.000       0.107       0.172
# C(product_id)[T.2135]                  -0.0271      0.017     -1.639      0.101      -0.059       0.005
# C(product_id)[T.2137]                   0.0157      0.017      0.952      0.341      -0.017       0.048
# C(product_id)[T.2139]                  -0.0177      0.017     -1.072      0.284      -0.050       0.015
# C(product_id)[T.2146]                   0.0332      0.017      2.007      0.045       0.001       0.066
# C(product_id)[T.2151]                   0.0362      0.017      2.188      0.029       0.004       0.069
# C(product_id)[T.2155]                   0.0028      0.017      0.170      0.865      -0.030       0.035
# C(product_id)[T.2173]                   0.0161      0.017      0.972      0.331      -0.016       0.048
# C(product_id)[T.2177]                   0.0714      0.017      4.319      0.000       0.039       0.104
# C(product_id)[T.2210]                   0.0044      0.017      0.263      0.792      -0.028       0.037
# C(product_id)[T.2215]                  -0.0234      0.017     -1.418      0.156      -0.056       0.009
# C(product_id)[T.2221]                   0.0343      0.017      2.075      0.038       0.002       0.067
# C(product_id)[T.2240]                  -0.0275      0.017     -1.667      0.096      -0.060       0.005
# C(product_id)[T.2259]                   0.0207      0.017      1.254      0.210      -0.012       0.053
# C(product_id)[T.2272]                  -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.2279]                  -0.0356      0.017     -2.156      0.031      -0.068      -0.003
# C(product_id)[T.2286]                  -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.2301]                  -0.0170      0.017     -1.030      0.303      -0.049       0.015
# C(product_id)[T.2314]                   0.0337      0.017      2.038      0.042       0.001       0.066
# C(product_id)[T.2324]                   0.1104      0.017      6.682      0.000       0.078       0.143
# C(product_id)[T.2341]                   0.1070      0.017      6.475      0.000       0.075       0.139
# C(product_id)[T.2345]                   0.0012      0.017      0.072      0.942      -0.031       0.034
# C(product_id)[T.2348]                   0.0358      0.017      2.167      0.030       0.003       0.068
# C(product_id)[T.2349]                  -0.0008      0.017     -0.051      0.959      -0.033       0.032
# C(product_id)[T.2350]                   0.1808      0.017     10.943      0.000       0.148       0.213
# C(product_id)[T.2353]                   0.0052      0.017      0.316      0.752      -0.027       0.038
# C(product_id)[T.2358]                   0.0168      0.017      1.015      0.310      -0.016       0.049
# C(product_id)[T.2362]                   0.0616      0.017      3.725      0.000       0.029       0.094
# C(product_id)[T.2370]                  -0.0178      0.017     -1.076      0.282      -0.050       0.015
# C(product_id)[T.2371]                   0.0194      0.017      1.177      0.239      -0.013       0.052
# C(product_id)[T.2373]                   0.0324      0.017      1.960      0.050   -3.32e-06       0.065
# C(product_id)[T.2420]                   0.0252      0.017      1.526      0.127      -0.007       0.058
# C(product_id)[T.2422]                   0.0207      0.017      1.255      0.210      -0.012       0.053
# C(product_id)[T.2423]                  -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.2435]                   0.0180      0.017      1.092      0.275      -0.014       0.050
# C(product_id)[T.2463]                  -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.2491]                   0.0164      0.017      0.992      0.321      -0.016       0.049
# C(product_id)[T.2493]                  -0.0569      0.017     -3.444      0.001      -0.089      -0.025
# C(product_id)[T.2512]                   0.0596      0.017      3.610      0.000       0.027       0.092
# C(product_id)[T.2525]                   0.0438      0.017      2.653      0.008       0.011       0.076
# C(product_id)[T.2529]                   0.0988      0.017      5.982      0.000       0.066       0.131
# C(product_id)[T.2563]                  -0.0077      0.017     -0.465      0.642      -0.040       0.025
# C(product_id)[T.2565]                   0.0152      0.017      0.922      0.356      -0.017       0.048
# C(product_id)[T.2571]                -1.42e+08   4.27e+08     -0.332      0.740   -9.79e+08    6.95e+08
# C(product_id)[T.2579]                   0.0141      0.017      0.856      0.392      -0.018       0.047
# C(product_id)[T.2593]                   0.0274      0.017      1.656      0.098      -0.005       0.060
# C(product_id)[T.2595]                   0.0845      0.017      5.114      0.000       0.052       0.117
# C(product_id)[T.2602]                   0.1855      0.017     11.226      0.000       0.153       0.218
# C(product_id)[T.2607]                  -0.0097      0.017     -0.586      0.558      -0.042       0.023
# C(product_id)[T.2611]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.2616]                  -0.0152      0.017     -0.921      0.357      -0.048       0.017
# C(product_id)[T.2631]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.2632]                  -0.0070      0.017     -0.426      0.670      -0.039       0.025
# C(product_id)[T.2668]                -1.42e+08   4.27e+08     -0.332      0.740   -9.79e+08    6.95e+08
# C(product_id)[T.2669]                   0.0040      0.017      0.240      0.810      -0.028       0.036
# C(product_id)[T.2677]                   0.0396      0.017      2.397      0.017       0.007       0.072
# C(product_id)[T.2720]                   0.0395      0.017      2.389      0.017       0.007       0.072
# C(product_id)[T.2735]                   0.0903      0.017      5.465      0.000       0.058       0.123
# C(product_id)[T.2736]                  -0.0221      0.017     -1.338      0.181      -0.054       0.010
# C(product_id)[T.2761]                  -0.0373      0.017     -2.259      0.024      -0.070      -0.005
# C(product_id)[T.2766]                   0.2915      0.017     17.642      0.000       0.259       0.324
# C(product_id)[T.2773]                   0.1655      0.017     10.018      0.000       0.133       0.198
# C(product_id)[T.2780]                   0.1793      0.017     10.852      0.000       0.147       0.212
# C(product_id)[T.2785]                   0.0014      0.017      0.083      0.934      -0.031       0.034
# C(product_id)[T.2789]                   0.0287      0.017      1.738      0.082      -0.004       0.061
# C(product_id)[T.2795]                   0.1158      0.017      7.007      0.000       0.083       0.148
# C(product_id)[T.2805]                   0.0203      0.017      1.228      0.219      -0.012       0.053
# C(product_id)[T.2808]                   0.0654      0.017      3.959      0.000       0.033       0.098
# C(product_id)[T.2809]                   0.0126      0.017      0.765      0.444      -0.020       0.045
# C(product_id)[T.2831]                   0.0413      0.017      2.498      0.012       0.009       0.074
# C(product_id)[T.2852]                   0.0150      0.017      0.908      0.364      -0.017       0.047
# C(product_id)[T.2862]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.2878]                  -0.0343      0.017     -2.075      0.038      -0.067      -0.002
# C(product_id)[T.2882]                  -0.0084      0.017     -0.506      0.613      -0.041       0.024
# C(product_id)[T.2891]                   0.2595      0.017     15.706      0.000       0.227       0.292
# C(product_id)[T.2898]                   0.0004      0.017      0.025      0.980      -0.032       0.033
# C(product_id)[T.2927]                  -0.0071      0.017     -0.430      0.667      -0.039       0.025
# C(product_id)[T.2939]                   0.1071      0.017      6.482      0.000       0.075       0.139
# C(product_id)[T.2945]                  -0.0057      0.017     -0.346      0.729      -0.038       0.027
# C(product_id)[T.2948]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.2951]                   0.0038      0.017      0.227      0.820      -0.029       0.036
# C(product_id)[T.2954]                   0.1007      0.017      6.093      0.000       0.068       0.133
# C(product_id)[T.2975]                  -0.0026      0.017     -0.158      0.874      -0.035       0.030
# C(product_id)[T.2979]                   0.0591      0.017      3.578      0.000       0.027       0.091
# C(product_id)[T.2987]                  -0.0288      0.017     -1.746      0.081      -0.061       0.004
# C(product_id)[T.2998]                   0.0054      0.017      0.325      0.745      -0.027       0.038
# C(product_id)[T.3019]                  -0.0005      0.017     -0.032      0.974      -0.033       0.032
# C(product_id)[T.3033]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3038]                   0.0542      0.017      3.279      0.001       0.022       0.087
# C(product_id)[T.3040]                  -0.0048      0.017     -0.290      0.772      -0.037       0.028
# C(product_id)[T.3068]                  -0.0026      0.017     -0.158      0.875      -0.035       0.030
# C(product_id)[T.3069]                   0.0781      0.017      4.727      0.000       0.046       0.110
# C(product_id)[T.3078]                  -0.0310      0.017     -1.878      0.060      -0.063       0.001
# C(product_id)[T.3086]                   0.0433      0.017      2.619      0.009       0.011       0.076
# C(product_id)[T.3103]                   0.0695      0.017      4.205      0.000       0.037       0.102
# C(product_id)[T.3104]                   0.0940      0.017      5.690      0.000       0.062       0.126
# C(product_id)[T.3109]                  -0.0393      0.017     -2.376      0.017      -0.072      -0.007
# C(product_id)[T.3143]                   0.0147      0.017      0.890      0.374      -0.018       0.047
# C(product_id)[T.3193]                   0.0029      0.017      0.175      0.861      -0.029       0.035
# C(product_id)[T.3208]                   0.1982      0.017     11.998      0.000       0.166       0.231
# C(product_id)[T.3250]                  -0.0021      0.017     -0.126      0.900      -0.034       0.030
# C(product_id)[T.3269]                  -0.0107      0.017     -0.647      0.517      -0.043       0.022
# C(product_id)[T.3281]                  -0.0036      0.017     -0.221      0.825      -0.036       0.029
# C(product_id)[T.3287]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3304]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3312]                   0.1070      0.017      6.479      0.000       0.075       0.139
# C(product_id)[T.3314]                   0.0321      0.017      1.941      0.052      -0.000       0.064
# C(product_id)[T.3318]                   0.0308      0.017      1.867      0.062      -0.002       0.063
# C(product_id)[T.3322]                   0.1375      0.017      8.324      0.000       0.105       0.170
# C(product_id)[T.3326]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3335]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3341]                   0.0389      0.017      2.352      0.019       0.006       0.071
# C(product_id)[T.3351]                  -0.0090      0.017     -0.547      0.584      -0.041       0.023
# C(product_id)[T.3356]                   0.0134      0.017      0.810      0.418      -0.019       0.046
# C(product_id)[T.3357]                   0.0255      0.017      1.543      0.123      -0.007       0.058
# C(product_id)[T.3361]                  -0.0206      0.017     -1.246      0.213      -0.053       0.012
# C(product_id)[T.3376]                   0.0568      0.017      3.438      0.001       0.024       0.089
# C(product_id)[T.3377]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3385]                   0.0205      0.017      1.242      0.214      -0.012       0.053
# C(product_id)[T.3386]                   0.0543      0.017      3.288      0.001       0.022       0.087
# C(product_id)[T.3387]                   0.0075      0.017      0.453      0.651      -0.025       0.040
# C(product_id)[T.3388]                   0.4301      0.017     26.030      0.000       0.398       0.462
# C(product_id)[T.3391]                   0.0172      0.017      1.040      0.298      -0.015       0.050
# C(product_id)[T.3397]                   0.0207      0.017      1.255      0.210      -0.012       0.053
# C(product_id)[T.3398]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3409]                  -0.0115      0.017     -0.694      0.488      -0.044       0.021
# C(product_id)[T.3419]                   0.0284      0.017      1.717      0.086      -0.004       0.061
# C(product_id)[T.3439]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3444]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3445]                   0.0395      0.017      2.394      0.017       0.007       0.072
# C(product_id)[T.3472]                   0.0403      0.017      2.441      0.015       0.008       0.073
# C(product_id)[T.3494]                   0.0434      0.017      2.629      0.009       0.011       0.076
# C(product_id)[T.3505]                   0.0068      0.017      0.415      0.678      -0.026       0.039
# C(product_id)[T.3523]                   0.2566      0.017     15.532      0.000       0.224       0.289
# C(product_id)[T.3527]                  -0.0074      0.017     -0.449      0.653      -0.040       0.025
# C(product_id)[T.3537]                   0.1489      0.017      9.014      0.000       0.117       0.181
# C(product_id)[T.3546]                   0.0121      0.017      0.735      0.463      -0.020       0.045
# C(product_id)[T.3559]                   0.1389      0.017      8.405      0.000       0.106       0.171
# C(product_id)[T.3562]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3563]                   0.0010      0.017      0.062      0.951      -0.031       0.033
# C(product_id)[T.3583]                  -0.0201      0.017     -1.215      0.224      -0.052       0.012
# C(product_id)[T.3584]                   0.0413      0.017      2.501      0.012       0.009       0.074
# C(product_id)[T.3590]                  -0.0010      0.017     -0.060      0.952      -0.033       0.031
# C(product_id)[T.3599]                   0.0486      0.017      2.939      0.003       0.016       0.081
# C(product_id)[T.3629]                  -0.0101      0.017     -0.610      0.542      -0.042       0.022
# C(product_id)[T.3651]                   0.0113      0.017      0.686      0.493      -0.021       0.044
# C(product_id)[T.3667]                   0.0002      0.017      0.010      0.992      -0.032       0.033
# C(product_id)[T.3676]                   0.0199      0.017      1.205      0.228      -0.012       0.052
# C(product_id)[T.3700]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3705]                  -0.0329      0.017     -1.991      0.046      -0.065      -0.001
# C(product_id)[T.3709]                   0.0036      0.017      0.218      0.827      -0.029       0.036
# C(product_id)[T.3724]                  -0.0120      0.017     -0.725      0.468      -0.044       0.020
# C(product_id)[T.3754]                  -0.0308      0.017     -1.866      0.062      -0.063       0.002
# C(product_id)[T.3755]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3771]                   0.0703      0.017      4.255      0.000       0.038       0.103
# C(product_id)[T.3792]                  -0.0267      0.017     -1.614      0.106      -0.059       0.006
# C(product_id)[T.3794]                   0.0359      0.017      2.172      0.030       0.004       0.068
# C(product_id)[T.3798]                   0.0209      0.017      1.265      0.206      -0.011       0.053
# C(product_id)[T.3854]                   0.0270      0.017      1.637      0.102      -0.005       0.059
# C(product_id)[T.3862]                  -0.0075      0.017     -0.453      0.651      -0.040       0.025
# C(product_id)[T.3884]                  -0.0120      0.017     -0.727      0.467      -0.044       0.020
# C(product_id)[T.3897]                   0.1046      0.017      6.328      0.000       0.072       0.137
# C(product_id)[T.3904]                   0.0763      0.017      4.620      0.000       0.044       0.109
# C(product_id)[T.3906]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3911]                   0.3013      0.017     18.238      0.000       0.269       0.334
# C(product_id)[T.3930]                   0.0024      0.017      0.147      0.883      -0.030       0.035
# C(product_id)[T.3952]                   0.0004      0.017      0.027      0.979      -0.032       0.033
# C(product_id)[T.3969]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3986]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.3990]                   0.0545      0.017      3.297      0.001       0.022       0.087
# C(product_id)[T.4009]                   0.1685      0.017     10.196      0.000       0.136       0.201
# C(product_id)[T.4011]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.4018]                   0.0151      0.017      0.913      0.361      -0.017       0.047
# C(product_id)[T.4032]                  -0.0043      0.017     -0.261      0.794      -0.037       0.028
# C(product_id)[T.4038]                   0.0391      0.017      2.364      0.018       0.007       0.071
# C(product_id)[T.4057]                  -0.0468      0.017     -2.831      0.005      -0.079      -0.014
# C(product_id)[T.4060]                   0.0787      0.017      4.763      0.000       0.046       0.111
# C(product_id)[T.4062]                   0.0269      0.017      1.628      0.103      -0.005       0.059
# C(product_id)[T.4070]                  -0.0029      0.017     -0.178      0.858      -0.035       0.029
# C(product_id)[T.4101]                   0.0762      0.017      4.613      0.000       0.044       0.109
# C(product_id)[T.4106]                  -0.0312      0.017     -1.888      0.059      -0.064       0.001
# C(product_id)[T.4118]                   0.0161      0.017      0.975      0.329      -0.016       0.048
# C(product_id)[T.4123]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.4125]                   0.0243      0.017      1.473      0.141      -0.008       0.057
# C(product_id)[T.4129]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.4132]                   0.0250      0.017      1.511      0.131      -0.007       0.057
# C(product_id)[T.4144]                -1.42e+08   4.27e+08     -0.332      0.740   -9.79e+08    6.95e+08
# C(product_id)[T.4158]                  -0.0198      0.017     -1.197      0.231      -0.052       0.013
# C(product_id)[T.4174]                   0.3390      0.017     20.518      0.000       0.307       0.371
# C(product_id)[T.4183]                   0.0319      0.017      1.932      0.053      -0.000       0.064
# C(product_id)[T.4194]                   0.0371      0.017      2.247      0.025       0.005       0.070
# C(product_id)[T.4200]                   0.0274      0.017      1.659      0.097      -0.005       0.060
# C(product_id)[T.4201]                   0.0128      0.017      0.772      0.440      -0.020       0.045
# C(product_id)[T.4202]                   0.3086      0.017     18.677      0.000       0.276       0.341
# C(product_id)[T.4223]                   0.1041      0.017      6.301      0.000       0.072       0.136
# C(product_id)[T.4248]                   0.1346      0.017      8.149      0.000       0.102       0.167
# C(product_id)[T.4280]                   0.0932      0.017      5.641      0.000       0.061       0.126
# C(product_id)[T.4291]                   0.2508      0.017     15.181      0.000       0.218       0.283
# C(product_id)[T.4293]                   0.0170      0.017      1.031      0.303      -0.015       0.049
# C(product_id)[T.4302]                   0.0416      0.017      2.519      0.012       0.009       0.074
# C(product_id)[T.4317]                  -0.0569      0.017     -3.443      0.001      -0.089      -0.025
# C(product_id)[T.4333]                   0.0042      0.017      0.256      0.798      -0.028       0.037
# C(product_id)[T.4341]                   0.0632      0.017      3.828      0.000       0.031       0.096
# C(product_id)[T.4346]                   0.0281      0.017      1.703      0.089      -0.004       0.061
# C(product_id)[T.4347]                  -0.0045      0.017     -0.270      0.787      -0.037       0.028
# C(product_id)[T.4351]                  -0.0006      0.017     -0.038      0.969      -0.033       0.032
# C(product_id)[T.4361]                  -0.0161      0.017     -0.976      0.329      -0.049       0.016
# C(month)[T.2]                           0.0169      0.017      0.995      0.320      -0.016       0.050
# C(month)[T.3]                           0.0048      0.017      0.291      0.771      -0.028       0.037
# C(day_of_week)[T.1]                    -0.0036      0.001     -2.801      0.005      -0.006      -0.001
# C(day_of_week)[T.2]                     0.0006      0.001      0.484      0.628      -0.002       0.003
# C(day_of_week)[T.3]                     0.0044      0.001      3.445      0.001       0.002       0.007
# C(day_of_week)[T.4]                     0.0166      0.001     12.699      0.000       0.014       0.019
# C(day_of_week)[T.5]                     0.0386      0.001     30.231      0.000       0.036       0.041
# C(day_of_week)[T.6]                     0.0469      0.001     36.708      0.000       0.044       0.049
# C(hour)[T.1]                           -0.0299      0.002    -12.590      0.000      -0.035      -0.025
# C(hour)[T.2]                           -0.0309      0.002    -12.982      0.000      -0.036      -0.026
# C(hour)[T.3]                           -0.0345      0.002    -14.536      0.000      -0.039      -0.030
# C(hour)[T.4]                           -0.0403      0.002    -16.959      0.000      -0.045      -0.036
# C(hour)[T.5]                           -0.0403      0.002    -16.959      0.000      -0.045      -0.036
# C(hour)[T.6]                           -0.0260      0.002    -10.950      0.000      -0.031      -0.021
# C(hour)[T.7]                           -0.0050      0.002     -2.112      0.035      -0.010      -0.000
# C(hour)[T.8]                           -0.0020      0.002     -0.861      0.389      -0.007       0.003
# C(hour)[T.9]                            0.0246      0.002     10.362      0.000       0.020       0.029
# C(hour)[T.10]                           0.0354      0.002     14.907      0.000       0.031       0.040
# C(hour)[T.11]                           0.0545      0.002     22.915      0.000       0.050       0.059
# C(hour)[T.12]                           0.0756      0.002     31.803      0.000       0.071       0.080
# C(hour)[T.13]                           0.0882      0.002     37.098      0.000       0.084       0.093
# C(hour)[T.14]                           0.0851      0.002     35.787      0.000       0.080       0.090
# C(hour)[T.15]                           0.0756      0.002     31.822      0.000       0.071       0.080
# C(hour)[T.16]                           0.0884      0.002     37.177      0.000       0.084       0.093
# C(hour)[T.17]                           0.1152      0.002     48.464      0.000       0.111       0.120
# C(hour)[T.18]                           0.1566      0.002     65.892      0.000       0.152       0.161
# C(hour)[T.19]                           0.1826      0.002     76.814      0.000       0.178       0.187
# C(hour)[T.20]                           0.1891      0.002     79.549      0.000       0.184       0.194
# C(hour)[T.21]                           0.1743      0.002     73.353      0.000       0.170       0.179
# C(hour)[T.22]                           0.1278      0.002     53.775      0.000       0.123       0.132
# C(hour)[T.23]                           0.0835      0.002     35.154      0.000       0.079       0.088
# C(product_id)[T.3]:C(month)[T.2]        0.0202      0.024      0.841      0.400      -0.027       0.067
# C(product_id)[T.23]:C(month)[T.2]      -0.0157      0.024     -0.653      0.513      -0.063       0.031
# C(product_id)[T.43]:C(month)[T.2]      -0.0157      0.024     -0.653      0.513      -0.063       0.031
# C(product_id)[T.45]:C(month)[T.2]      -0.0157      0.024     -0.653      0.513      -0.063       0.031
# C(product_id)[T.54]:C(month)[T.2]      -0.0361      0.024     -1.505      0.132      -0.083       0.011
# C(product_id)[T.59]:C(month)[T.2]      -0.0437      0.024     -1.824      0.068      -0.091       0.003
# C(product_id)[T.78]:C(month)[T.2]       0.0528      0.024      2.202      0.028       0.006       0.100
# C(product_id)[T.85]:C(month)[T.2]      -0.0397      0.024     -1.657      0.098      -0.087       0.007
# C(product_id)[T.86]:C(month)[T.2]      -0.0064      0.024     -0.269      0.788      -0.053       0.041
# C(product_id)[T.89]:C(month)[T.2]      -0.0222      0.024     -0.925      0.355      -0.069       0.025
# C(product_id)[T.125]:C(month)[T.2]     -0.0238      0.024     -0.992      0.321      -0.071       0.023
# C(product_id)[T.133]:C(month)[T.2]     -0.0524      0.024     -2.186      0.029      -0.099      -0.005
# C(product_id)[T.139]:C(month)[T.2]     -0.0402      0.024     -1.675      0.094      -0.087       0.007
# C(product_id)[T.147]:C(month)[T.2]     -0.0234      0.024     -0.974      0.330      -0.070       0.024
# C(product_id)[T.161]:C(month)[T.2]      0.0336      0.024      1.402      0.161      -0.013       0.081
# C(product_id)[T.174]:C(month)[T.2]     -0.0379      0.024     -1.583      0.114      -0.085       0.009
# C(product_id)[T.204]:C(month)[T.2]     -0.0021      0.024     -0.086      0.931      -0.049       0.045
# C(product_id)[T.206]:C(month)[T.2]     -0.0124      0.024     -0.518      0.604      -0.059       0.035
# C(product_id)[T.210]:C(month)[T.2]      0.0033      0.024      0.138      0.890      -0.044       0.050
# C(product_id)[T.218]:C(month)[T.2]      0.0074      0.024      0.309      0.757      -0.040       0.054
# ...
# C(product_id)[T.2789]:C(month)[T.3]    -0.0081      0.023     -0.347      0.729      -0.054       0.038
# C(product_id)[T.2795]:C(month)[T.3]     0.0179      0.023      0.766      0.444      -0.028       0.064
# C(product_id)[T.2805]:C(month)[T.3]     0.0257      0.023      1.100      0.271      -0.020       0.071
# C(product_id)[T.2808]:C(month)[T.3]    -0.0340      0.023     -1.457      0.145      -0.080       0.012
# C(product_id)[T.2809]:C(month)[T.3]     0.0133      0.023      0.571      0.568      -0.032       0.059
# C(product_id)[T.2831]:C(month)[T.3]     0.0064      0.023      0.273      0.785      -0.039       0.052
# C(product_id)[T.2852]:C(month)[T.3]    -0.0016      0.023     -0.068      0.946      -0.047       0.044
# C(product_id)[T.2862]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.2878]:C(month)[T.3]     0.0104      0.023      0.445      0.657      -0.035       0.056
# C(product_id)[T.2882]:C(month)[T.3]     0.0202      0.023      0.863      0.388      -0.026       0.066
# C(product_id)[T.2891]:C(month)[T.3]     0.0114      0.023      0.489      0.625      -0.034       0.057
# C(product_id)[T.2898]:C(month)[T.3]     0.0081      0.023      0.348      0.728      -0.038       0.054
# C(product_id)[T.2927]:C(month)[T.3]     0.0024      0.023      0.105      0.917      -0.043       0.048
# C(product_id)[T.2939]:C(month)[T.3]     0.0077      0.023      0.328      0.743      -0.038       0.053
# C(product_id)[T.2945]:C(month)[T.3]    -0.0240      0.023     -1.028      0.304      -0.070       0.022
# C(product_id)[T.2948]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.2951]:C(month)[T.3]    -0.0015      0.023     -0.065      0.949      -0.047       0.044
# C(product_id)[T.2954]:C(month)[T.3]    -0.0159      0.023     -0.682      0.495      -0.062       0.030
# C(product_id)[T.2975]:C(month)[T.3]    -0.0239      0.023     -1.025      0.305      -0.070       0.022
# C(product_id)[T.2979]:C(month)[T.3]    -0.0394      0.023     -1.686      0.092      -0.085       0.006
# C(product_id)[T.2987]:C(month)[T.3]     0.0033      0.023      0.142      0.887      -0.042       0.049
# C(product_id)[T.2998]:C(month)[T.3]    -0.0078      0.023     -0.336      0.737      -0.054       0.038
# C(product_id)[T.3019]:C(month)[T.3]    -0.0102      0.023     -0.437      0.662      -0.056       0.036
# C(product_id)[T.3033]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.3038]:C(month)[T.3]    -0.0310      0.023     -1.328      0.184      -0.077       0.015
# C(product_id)[T.3040]:C(month)[T.3]     0.0003      0.023      0.012      0.990      -0.045       0.046
# C(product_id)[T.3068]:C(month)[T.3]    -0.0163      0.023     -0.698      0.485      -0.062       0.029
# C(product_id)[T.3069]:C(month)[T.3]    -0.0239      0.023     -1.022      0.307      -0.070       0.022
# C(product_id)[T.3078]:C(month)[T.3]     0.0233      0.023      1.000      0.317      -0.022       0.069
# C(product_id)[T.3086]:C(month)[T.3]    -0.0221      0.023     -0.944      0.345      -0.068       0.024
# C(product_id)[T.3103]:C(month)[T.3]    -0.0345      0.023     -1.475      0.140      -0.080       0.011
# C(product_id)[T.3104]:C(month)[T.3]     0.0017      0.023      0.071      0.943      -0.044       0.047
# C(product_id)[T.3109]:C(month)[T.3]     0.0238      0.023      1.019      0.308      -0.022       0.070
# C(product_id)[T.3143]:C(month)[T.3]     0.0053      0.023      0.228      0.819      -0.040       0.051
# C(product_id)[T.3193]:C(month)[T.3]    -0.0162      0.023     -0.692      0.489      -0.062       0.030
# C(product_id)[T.3208]:C(month)[T.3]     0.0109      0.023      0.468      0.640      -0.035       0.057
# C(product_id)[T.3250]:C(month)[T.3]    -0.0144      0.023     -0.616      0.538      -0.060       0.031
# C(product_id)[T.3269]:C(month)[T.3]     0.0060      0.023      0.257      0.797      -0.040       0.052
# C(product_id)[T.3281]:C(month)[T.3]     0.0290      0.023      1.243      0.214      -0.017       0.075
# C(product_id)[T.3287]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.3304]:C(month)[T.3]     0.0311      0.023      1.332      0.183      -0.015       0.077
# C(product_id)[T.3312]:C(month)[T.3]    -0.0442      0.023     -1.891      0.059      -0.090       0.002
# C(product_id)[T.3314]:C(month)[T.3] -7.636e-05      0.023     -0.003      0.997      -0.046       0.046
# C(product_id)[T.3318]:C(month)[T.3]    -0.0144      0.023     -0.619      0.536      -0.060       0.031
# C(product_id)[T.3322]:C(month)[T.3]     0.0117      0.023      0.501      0.617      -0.034       0.057
# C(product_id)[T.3326]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.3335]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.3341]:C(month)[T.3]    -0.0011      0.023     -0.047      0.962      -0.047       0.045
# C(product_id)[T.3351]:C(month)[T.3]     0.0107      0.023      0.457      0.648      -0.035       0.056
# C(product_id)[T.3356]:C(month)[T.3]    -0.0192      0.023     -0.822      0.411      -0.065       0.027
# C(product_id)[T.3357]:C(month)[T.3]     0.0060      0.023      0.258      0.796      -0.040       0.052
# C(product_id)[T.3361]:C(month)[T.3]     0.0044      0.023      0.187      0.851      -0.041       0.050
# C(product_id)[T.3376]:C(month)[T.3]    -0.0216      0.023     -0.923      0.356      -0.067       0.024
# C(product_id)[T.3377]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.3385]:C(month)[T.3]    -0.0289      0.023     -1.237      0.216      -0.075       0.017
# C(product_id)[T.3386]:C(month)[T.3]    -0.0079      0.023     -0.339      0.735      -0.054       0.038
# C(product_id)[T.3387]:C(month)[T.3]     0.0389      0.023      1.665      0.096      -0.007       0.085
# C(product_id)[T.3388]:C(month)[T.3]    -0.1075      0.023     -4.602      0.000      -0.153      -0.062
# C(product_id)[T.3391]:C(month)[T.3]    -0.0246      0.023     -1.051      0.293      -0.070       0.021
# C(product_id)[T.3397]:C(month)[T.3]    -0.0170      0.023     -0.726      0.468      -0.063       0.029
# C(product_id)[T.3398]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.3409]:C(month)[T.3]    -0.0121      0.023     -0.520      0.603      -0.058       0.034
# C(product_id)[T.3419]:C(month)[T.3]    -0.0363      0.023     -1.553      0.120      -0.082       0.010
# C(product_id)[T.3439]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.3444]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.3445]:C(month)[T.3]    -0.0069      0.023     -0.293      0.769      -0.053       0.039
# C(product_id)[T.3472]:C(month)[T.3]    -0.0116      0.023     -0.497      0.619      -0.057       0.034
# C(product_id)[T.3494]:C(month)[T.3]    -0.0148      0.023     -0.634      0.526      -0.061       0.031
# C(product_id)[T.3505]:C(month)[T.3]     0.0036      0.023      0.155      0.877      -0.042       0.049
# C(product_id)[T.3523]:C(month)[T.3]    -0.0174      0.023     -0.744      0.457      -0.063       0.028
# C(product_id)[T.3527]:C(month)[T.3]    -0.0074      0.023     -0.318      0.750      -0.053       0.038
# C(product_id)[T.3537]:C(month)[T.3]    -0.0634      0.023     -2.716      0.007      -0.109      -0.018
# C(product_id)[T.3546]:C(month)[T.3]    -0.0183      0.023     -0.786      0.432      -0.064       0.027
# C(product_id)[T.3559]:C(month)[T.3]    -0.0152      0.023     -0.649      0.516      -0.061       0.031
# C(product_id)[T.3562]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.3563]:C(month)[T.3]    -0.0093      0.023     -0.398      0.690      -0.055       0.036
# C(product_id)[T.3583]:C(month)[T.3]     0.0167      0.023      0.713      0.476      -0.029       0.062
# C(product_id)[T.3584]:C(month)[T.3]    -0.0318      0.023     -1.364      0.173      -0.078       0.014
# C(product_id)[T.3590]:C(month)[T.3]     0.0049      0.023      0.212      0.832      -0.041       0.051
# C(product_id)[T.3599]:C(month)[T.3]     0.0186      0.023      0.797      0.425      -0.027       0.064
# C(product_id)[T.3629]:C(month)[T.3]     0.0345      0.023      1.478      0.139      -0.011       0.080
# C(product_id)[T.3651]:C(month)[T.3]    -0.0107      0.023     -0.458      0.647      -0.056       0.035
# C(product_id)[T.3667]:C(month)[T.3]     0.0136      0.023      0.583      0.560      -0.032       0.059
# C(product_id)[T.3676]:C(month)[T.3]     0.0154      0.023      0.659      0.510      -0.030       0.061
# C(product_id)[T.3700]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.3705]:C(month)[T.3]     0.0346      0.023      1.481      0.139      -0.011       0.080
# C(product_id)[T.3709]:C(month)[T.3]    -0.0098      0.023     -0.419      0.675      -0.056       0.036
# C(product_id)[T.3724]:C(month)[T.3]    -0.0128      0.023     -0.546      0.585      -0.059       0.033
# C(product_id)[T.3754]:C(month)[T.3]    -0.0112      0.023     -0.479      0.632      -0.057       0.035
# C(product_id)[T.3755]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.3771]:C(month)[T.3]    -0.0312      0.023     -1.337      0.181      -0.077       0.015
# C(product_id)[T.3792]:C(month)[T.3]     0.0209      0.023      0.896      0.370      -0.025       0.067
# C(product_id)[T.3794]:C(month)[T.3]    -0.0194      0.023     -0.831      0.406      -0.065       0.026
# C(product_id)[T.3798]:C(month)[T.3]    -0.0138      0.023     -0.589      0.556      -0.060       0.032
# C(product_id)[T.3854]:C(month)[T.3]     0.0023      0.023      0.097      0.923      -0.044       0.048
# C(product_id)[T.3862]:C(month)[T.3]    -0.0154      0.023     -0.661      0.509      -0.061       0.030
# C(product_id)[T.3884]:C(month)[T.3]     0.0268      0.023      1.149      0.250      -0.019       0.073
# C(product_id)[T.3897]:C(month)[T.3]    -0.0090      0.023     -0.387      0.698      -0.055       0.037
# C(product_id)[T.3904]:C(month)[T.3]    -0.0200      0.023     -0.857      0.391      -0.066       0.026
# C(product_id)[T.3906]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.3911]:C(month)[T.3]     0.0874      0.023      3.740      0.000       0.042       0.133
# C(product_id)[T.3930]:C(month)[T.3]    -0.0243      0.023     -1.038      0.299      -0.070       0.022
# C(product_id)[T.3952]:C(month)[T.3]    -0.0013      0.023     -0.055      0.956      -0.047       0.045
# C(product_id)[T.3969]:C(month)[T.3]     0.0191      0.023      0.817      0.414      -0.027       0.065
# C(product_id)[T.3986]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.3990]:C(month)[T.3]    -0.0257      0.023     -1.102      0.271      -0.072       0.020
# C(product_id)[T.4009]:C(month)[T.3]    -0.0209      0.023     -0.897      0.370      -0.067       0.025
# C(product_id)[T.4011]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.4018]:C(month)[T.3]    -0.0016      0.023     -0.068      0.946      -0.047       0.044
# C(product_id)[T.4032]:C(month)[T.3]     0.0164      0.023      0.704      0.481      -0.029       0.062
# C(product_id)[T.4038]:C(month)[T.3]    -0.0254      0.023     -1.089      0.276      -0.071       0.020
# C(product_id)[T.4057]:C(month)[T.3]     0.0586      0.023      2.511      0.012       0.013       0.104
# C(product_id)[T.4060]:C(month)[T.3]    -0.0382      0.023     -1.637      0.102      -0.084       0.008
# C(product_id)[T.4062]:C(month)[T.3]     0.0230      0.023      0.985      0.325      -0.023       0.069
# C(product_id)[T.4070]:C(month)[T.3]     0.0081      0.023      0.349      0.727      -0.038       0.054
# C(product_id)[T.4101]:C(month)[T.3]    -0.0207      0.023     -0.885      0.376      -0.066       0.025
# C(product_id)[T.4106]:C(month)[T.3]     0.0612      0.023      2.621      0.009       0.015       0.107
# C(product_id)[T.4118]:C(month)[T.3]    -0.0270      0.023     -1.155      0.248      -0.073       0.019
# C(product_id)[T.4123]:C(month)[T.3]     0.0047      0.023      0.202      0.840      -0.041       0.050
# C(product_id)[T.4125]:C(month)[T.3]    -0.0243      0.023     -1.041      0.298      -0.070       0.021
# C(product_id)[T.4129]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.4132]:C(month)[T.3]     0.0331      0.023      1.418      0.156      -0.013       0.079
# C(product_id)[T.4144]:C(month)[T.3]     0.0680      0.023      2.908      0.004       0.022       0.114
# C(product_id)[T.4158]:C(month)[T.3]     0.0335      0.023      1.434      0.151      -0.012       0.079
# C(product_id)[T.4174]:C(month)[T.3]    -0.0666      0.023     -2.849      0.004      -0.112      -0.021
# C(product_id)[T.4183]:C(month)[T.3]    -0.0365      0.023     -1.563      0.118      -0.082       0.009
# C(product_id)[T.4194]:C(month)[T.3]     0.0114      0.023      0.488      0.626      -0.034       0.057
# C(product_id)[T.4200]:C(month)[T.3]    -0.0013      0.023     -0.054      0.957      -0.047       0.045
# C(product_id)[T.4201]:C(month)[T.3]    -0.0164      0.023     -0.703      0.482      -0.062       0.029
# C(product_id)[T.4202]:C(month)[T.3]    -0.0709      0.023     -3.036      0.002      -0.117      -0.025
# C(product_id)[T.4223]:C(month)[T.3]    -0.0700      0.023     -2.997      0.003      -0.116      -0.024
# C(product_id)[T.4248]:C(month)[T.3]     0.0151      0.023      0.648      0.517      -0.031       0.061
# C(product_id)[T.4280]:C(month)[T.3]    -0.0228      0.023     -0.978      0.328      -0.069       0.023
# C(product_id)[T.4291]:C(month)[T.3]    -0.0256      0.023     -1.095      0.273      -0.071       0.020
# C(product_id)[T.4293]:C(month)[T.3]    -0.0029      0.023     -0.123      0.902      -0.049       0.043
# C(product_id)[T.4302]:C(month)[T.3]     0.1223      0.023      5.236      0.000       0.077       0.168
# C(product_id)[T.4317]:C(month)[T.3]    -0.0020      0.023     -0.084      0.933      -0.048       0.044
# C(product_id)[T.4333]:C(month)[T.3]     0.0382      0.023      1.635      0.102      -0.008       0.084
# C(product_id)[T.4341]:C(month)[T.3]     0.0412      0.023      1.766      0.077      -0.005       0.087
# C(product_id)[T.4346]:C(month)[T.3]    -0.0460      0.023     -1.968      0.049      -0.092      -0.000
# C(product_id)[T.4347]:C(month)[T.3]    -0.0035      0.023     -0.151      0.880      -0.049       0.042
# C(product_id)[T.4351]:C(month)[T.3]    -0.0046      0.023     -0.196      0.844      -0.050       0.041
# C(product_id)[T.4361]:C(month)[T.3]    -0.0036      0.023     -0.153      0.879      -0.049       0.042
# stockout_dum                           -0.0022      0.001     -1.815      0.069      -0.005       0.000
# com_dum                               1.42e+08   4.27e+08      0.332      0.740   -6.95e+08    9.79e+08
# stockout_com_interaction               -0.0328      0.009     -3.688      0.000      -0.050      -0.015
# ==============================================================================
# Omnibus:                   629983.483   Durbin-Watson:                   1.766
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         13443315.538
# Skew:                           3.343   Prob(JB):                         0.00
# Kurtosis:                      21.157   Cond. No.                     4.19e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.95e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
summary_table = pd.read_csv('summary_table_3834.csv')

# %%
# Get the current headers of the DataFrame
current_headers = list(summary_table.columns)

# Create a new DataFrame with the duplicated headers
header_row = pd.DataFrame([current_headers], columns=summary_table.columns)

# Concatenate the header row with the original summary_table DataFrame
summary_table = pd.concat([header_row, summary_table], ignore_index=True)

# %%
headers = ['Variable', 'Model_with_FixedEffects', 'Model_without_FixedEffects']
# Add the headers to the DataFrame
summary_table.columns = headers

# %%
# Replace "day" with "product"
summary_table['Variable'] = summary_table['Variable'].replace('day', 'product')

# Rearrange the columns
summary_table = summary_table[['Variable', 'Model_without_FixedEffects', 'Model_with_FixedEffects']]

# %%
summary_table
# Out:
#                    Variable Model_without_FixedEffects  \
# 0              stockout_dum         0.0073 (0.0012)***
# 1                   com_dum         0.1184 (0.0020)***
# 2  stockout_com_interaction        -0.0326 (0.0088)***
# 3                     month                         no
# 4                   product                         no
# 5               day_of_week                         no
# 6                      hour                         no
# 7                 R-squared                     0.0020
# 8          No. Observations                1,733,256.0
#
#             Model_with_FixedEffects
# 0                  -0.0015 (0.0011)
# 1  -117042603.4502 (443410914.2873)
# 2               -0.0326 (0.0080)***
# 3                               yes
# 4                               yes
# 5                               yes
# 6                               yes
# 7                            0.1664
# 8                       1,733,256.0

# %%
from tabulate import tabulate

# Function to determine significance level
def get_significance(p_value):
    if p_value < 0.001:
        return '***'
    elif p_value < 0.01:
        return '**'
    elif p_value < 0.05:
        return '*'
    else:
        return ''

# Create the summary table in a list format
summary_table_aux = []

# Add the coefficient, standard error, and significance level rows
summary_table_aux.append(['stockout_dum', '{:.4f} ({:.4f}){}'.format(model_with_product_month_effects.params['stockout_dum'], model_with_product_month_effects.bse['stockout_dum'], get_significance(model_with_product_month_effects.pvalues['stockout_dum']))])
summary_table_aux.append(['com_dum', '{:.4f} ({:.4f}){}'.format(model_with_product_month_effects.params['com_dum'], model_with_product_month_effects.bse['com_dum'], get_significance(model_with_product_month_effects.pvalues['com_dum']))])
summary_table_aux.append(['stockout_com_interaction', '{:.4f} ({:.4f}){}'.format(model_with_product_month_effects.params['stockout_com_interaction'], model_with_product_month_effects.bse['stockout_com_interaction'], get_significance(model_with_product_month_effects.pvalues['stockout_com_interaction']))])

# Add the inclusion information
summary_table_aux.append(['month', 'yes'])
summary_table_aux.append(['product', 'yes'])
summary_table_aux.append(['day_of_week', 'yes'])
summary_table_aux.append(['hour', 'yes'])

summary_table_aux.append(['R-squared', '{:.4f}'.format(model_with_product_month_effects.rsquared)])

summary_table_aux.append(['No. Observations', '{:,}'.format(model_with_product_month_effects.nobs)])

# Create the table headers
headers = ['Variable', 'Model_with_All_FixedEffects']

# Print the summary table using tabulate
print(tabulate(summary_table_aux, headers, tablefmt="grid"))
# Out:
# +--------------------------+---------------------------------+
# | Variable                 | Model_with_All_FixedEffects     |
# +==========================+=================================+
# | stockout_dum             | -0.0022 (0.0012)                |
# +--------------------------+---------------------------------+
# | com_dum                  | 141997725.9534 (427146594.8403) |
# +--------------------------+---------------------------------+
# | stockout_com_interaction | -0.0328 (0.0089)***             |
# +--------------------------+---------------------------------+
# | month                    | yes                             |
# +--------------------------+---------------------------------+
# | product                  | yes                             |
# +--------------------------+---------------------------------+
# | day_of_week              | yes                             |
# +--------------------------+---------------------------------+
# | hour                     | yes                             |
# +--------------------------+---------------------------------+
# | R-squared                | 0.1791                          |
# +--------------------------+---------------------------------+
# | No. Observations         | 861,840.0                       |
# +--------------------------+---------------------------------+

# %%
summary_table_aux
# Out:
# [['stockout_dum', '-0.0022 (0.0012)'],
#  ['com_dum', '141997725.9534 (427146594.8403)'],
#  ['stockout_com_interaction', '-0.0328 (0.0089)***'],
#  ['month', 'yes'],
#  ['product', 'yes'],
#  ['day_of_week', 'yes'],
#  ['hour', 'yes'],
#  ['R-squared', '0.1791'],
#  ['No. Observations', '861,840.0']]

# %%
summary_table
# Out:
#                    Variable Model_without_FixedEffects  \
# 0              stockout_dum         0.0073 (0.0012)***
# 1                   com_dum         0.1184 (0.0020)***
# 2  stockout_com_interaction        -0.0326 (0.0088)***
# 3                     month                         no
# 4                   product                         no
# 5               day_of_week                         no
# 6                      hour                         no
# 7                 R-squared                     0.0020
# 8          No. Observations                1,733,256.0
#
#             Model_with_FixedEffects
# 0                  -0.0015 (0.0011)
# 1  -117042603.4502 (443410914.2873)
# 2               -0.0326 (0.0080)***
# 3                               yes
# 4                               yes
# 5                               yes
# 6                               yes
# 7                            0.1664
# 8                       1,733,256.0

# %%
# Create a new column with the values from summary_table_aux
summary_table['Model_with_All_FixedEffects'] = [row[1] for row in summary_table_aux]

# Print the updated summary_table DataFrame
print(summary_table)
# Out:
#                    Variable Model_without_FixedEffects  \
# 0              stockout_dum         0.0073 (0.0012)***
# 1                   com_dum         0.1184 (0.0020)***
# 2  stockout_com_interaction        -0.0326 (0.0088)***
# 3                     month                         no
# 4                   product                         no
# 5               day_of_week                         no
# 6                      hour                         no
# 7                 R-squared                     0.0020
# 8          No. Observations                1,733,256.0
#
#             Model_with_FixedEffects      Model_with_All_FixedEffects
# 0                  -0.0015 (0.0011)                 -0.0022 (0.0012)
# 1  -117042603.4502 (443410914.2873)  141997725.9534 (427146594.8403)
# 2               -0.0326 (0.0080)***              -0.0328 (0.0089)***
# 3                               yes                              yes
# 4                               yes                              yes
# 5                               yes                              yes
# 6                               yes                              yes
# 7                            0.1664                           0.1791
# 8                       1,733,256.0                        861,840.0

# %%
# Create a new row for product:month
new_row_product_month = ['product:month', 'no', 'no', 'yes']

# Find the index position of the "hour" row
hour_index = summary_table.index[summary_table['Variable'] == 'hour'][0]

# Insert the new row below the hour row
summary_table = summary_table.append(pd.Series(new_row_product_month, index=summary_table.columns), ignore_index=True)
summary_table = pd.concat([summary_table.iloc[:hour_index + 1], summary_table.iloc[-1:], summary_table.iloc[hour_index + 1:-1]], ignore_index=True)

# Print the updated summary_table DataFrame
print(summary_table)
# Out:
#                    Variable Model_without_FixedEffects  \
# 0              stockout_dum         0.0073 (0.0012)***
# 1                   com_dum         0.1184 (0.0020)***
# 2  stockout_com_interaction        -0.0326 (0.0088)***
# 3                     month                         no
# 4                   product                         no
# 5               day_of_week                         no
# 6                      hour                         no
# 7             product:month                         no
# 8                 R-squared                     0.0020
# 9          No. Observations                1,733,256.0
#
#             Model_with_FixedEffects      Model_with_All_FixedEffects
# 0                  -0.0015 (0.0011)                 -0.0022 (0.0012)
# 1  -117042603.4502 (443410914.2873)  141997725.9534 (427146594.8403)
# 2               -0.0326 (0.0080)***              -0.0328 (0.0089)***
# 3                               yes                              yes
# 4                               yes                              yes
# 5                               yes                              yes
# 6                               yes                              yes
# 7                                no                              yes
# 8                            0.1664                           0.1791
# 9                       1,733,256.0                        861,840.0
# <ipython-input-82-642f19906446>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summary_table = summary_table.append(pd.Series(new_row_product_month, index=summary_table.columns), ignore_index=True)

# %%
summary_table
# Out:
#                    Variable Model_without_FixedEffects  \
# 0              stockout_dum         0.0073 (0.0012)***
# 1                   com_dum         0.1184 (0.0020)***
# 2  stockout_com_interaction        -0.0326 (0.0088)***
# 3                     month                         no
# 4                   product                         no
# 5               day_of_week                         no
# 6                      hour                         no
# 7             product:month                         no
# 8                 R-squared                     0.0020
# 9          No. Observations                1,733,256.0
#
#             Model_with_FixedEffects      Model_with_All_FixedEffects
# 0                  -0.0015 (0.0011)                 -0.0022 (0.0012)
# 1  -117042603.4502 (443410914.2873)  141997725.9534 (427146594.8403)
# 2               -0.0326 (0.0080)***              -0.0328 (0.0089)***
# 3                               yes                              yes
# 4                               yes                              yes
# 5                               yes                              yes
# 6                               yes                              yes
# 7                                no                              yes
# 8                            0.1664                           0.1791
# 9                       1,733,256.0                        861,840.0
